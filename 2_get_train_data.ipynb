# %%
import os
import json
import pickle
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import yfinance as yf
from src.db import DataBase
import matplotlib.pyplot as plt
from src.utils_general import beeps
from src.utils_stocks import get_df_c
from src.utils_general import get_df_sym
from src.utils_general import plot_divergences
from src.utils_date import get_ls_date_str_from_db
with open('dir.txt') as f: dir_db = json.load(f)['dir_db']
with open('dir.txt') as f: dir_train = json.load(f)['dir_train']
with open('dir.txt') as f: dir_models = json.load(f)['dir_models']
db = DataBase([], dir_db=dir_db)

live_data = 0
target_profit = 0.011
target_loss = -0.031
ls_date_str = get_ls_date_str_from_db('2020-11-30', '2022-01-01', db) #'2020-06-23'
print(ls_date_str[0], ls_date_str[-1])
# Out:
# 2020-11-30 2020-12-11

# %%
count, count_e = 0, 0
ls_df_t = []
for date_str in ls_date_str:
    df_sym = get_df_sym(db, date_str)
    for i, tup in df_sym.iterrows():
        count+=1
        if i%100==0: print(i+1, df_sym.shape[0], date_str)
        try:
            df_c = get_df_c(tup['sym'], date_str, live_data, db, target_profit, target_loss)
            ls_df_t.append(df_c[df_c['divergence']!=''])
        except Exception as e:
            print(tup['sym'], type(e).__name__, e)
            count_e+=1
print('Errors:', count_e, count, round(count_e/count, 3))
# Out:
# 1 2192 2020-11-30
# AEIS Exception No intraday(minute interval) data for previous day!
# CSGP Exception No intraday(minute interval) data for previous day!
# WAFD Exception No intraday(minute interval) data for previous day!
# TDG Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# DOOR Exception No intraday(minute interval) data for previous day!
# GFF Exception No intraday(minute interval) data for previous day!
# CASA Exception No intraday(minute interval) data for previous day!
# EGBN Exception No intraday(minute interval) data for previous day!
# STC Exception No intraday(minute interval) data for previous day!
# CNA Exception No intraday(minute interval) data for previous day!
# CACC Exception No intraday(minute interval) data for previous day!
# ALLK Exception No intraday(minute interval) data for previous day!
# 101 2192 2020-11-30
# ENV Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# REPL Exception No intraday(minute interval) data for previous day!
# CLDT Exception No intraday(minute interval) data for previous day!
# AIKI Exception No intraday(minute interval) data for previous day!
# DTEA Exception No intraday(minute interval) data for previous day!
# TYME Exception No intraday(minute interval) data for previous day!
# CGBD Exception No intraday(minute interval) data for previous day!
# LOPE Exception No intraday(minute interval) data for previous day!
# SPH Exception No intraday(minute interval) data for previous day!
# DRQ Exception No intraday(minute interval) data for previous day!
# MEI Exception No intraday(minute interval) data for previous day!
# 201 2192 2020-11-30
# ENZ Exception No intraday(minute interval) data for previous day!
# ATOM Exception Less than 200 Data points for today (153), skipping!
# DESP Exception Less than 200 Data points for today (179), skipping!
# XLRN Exception No intraday(minute interval) data for previous day!
# WOR Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# VYGR Exception No intraday(minute interval) data for previous day!
# APOG Exception No intraday(minute interval) data for previous day!
# MTLS Exception No intraday(minute interval) data for previous day!
# FIBK Exception No intraday(minute interval) data for previous day!
# CPHI Exception Less than 200 Data points for today (191), skipping!
# UTF Exception No intraday(minute interval) data for previous day!
# 301 2192 2020-11-30
# OXSQ Exception No intraday(minute interval) data for previous day!
# PTGX Exception No intraday(minute interval) data for previous day!
# TBPH Exception No intraday(minute interval) data for previous day!
# XNCR Exception No intraday(minute interval) data for previous day!
# DAVA Exception No intraday(minute interval) data for previous day!
# AGLE Exception No intraday(minute interval) data for previous day!
# CSTL Exception No intraday(minute interval) data for previous day!
# ROAD Exception No intraday(minute interval) data for previous day!
# SLDB Exception No intraday(minute interval) data for previous day!
# GOOD Exception No intraday(minute interval) data for previous day!
# LOVE Exception No intraday(minute interval) data for previous day!
# MX Exception Less than 200 Data points for today (162), skipping!
# OSMT Exception No intraday(minute interval) data for previous day!
# SWTX Exception No intraday(minute interval) data for previous day!
# IPGP Exception No intraday(minute interval) data for previous day!
# KOF Exception No intraday(minute interval) data for previous day!
# SPNS Exception No intraday(minute interval) data for previous day!
# 401 2192 2020-11-30
# SGRY Exception No intraday(minute interval) data for previous day!
# FRPT Exception No intraday(minute interval) data for previous day!
# KIDS Exception No intraday(minute interval) data for previous day!
# COLL Exception No intraday(minute interval) data for previous day!
# VNTR Exception No intraday(minute interval) data for previous day!
# ADTN Exception No intraday(minute interval) data for previous day!
# CAAP Exception No intraday(minute interval) data for previous day!
# EVR Exception Less than 200 Data points for today (195), skipping!
# ETW Exception No intraday(minute interval) data for previous day!
# IMAB Exception No intraday(minute interval) data for previous day!
# GNLN Exception No intraday(minute interval) data for previous day!
# SMG Exception No intraday(minute interval) data for previous day!
# GWB Exception No intraday(minute interval) data for previous day!
# CDMO Exception No intraday(minute interval) data for previous day!
# MKTX Exception No intraday(minute interval) data for previous day!
# 501 2192 2020-11-30
# MTEM Exception Less than 200 Data points for today (165), skipping!
# TG Exception No intraday(minute interval) data for previous day!
# ABMD Exception No intraday(minute interval) data for previous day!
# BPMP Exception No intraday(minute interval) data for previous day!
# CYCN Exception Less than 200 Data points for today (180), skipping!
# NDSN Exception No intraday(minute interval) data for previous day!
# ABM Exception No intraday(minute interval) data for previous day!
# FEI Exception No intraday(minute interval) data for previous day!
# ARCE Exception No intraday(minute interval) data for previous day!
# 601 2192 2020-11-30
# BNFT Exception No intraday(minute interval) data for previous day!
# LAND Exception No intraday(minute interval) data for previous day!
# CENTA Exception Less than 200 Data points for today (198), skipping!
# FOE Exception No intraday(minute interval) data for previous day!
# UTG Exception No intraday(minute interval) data for previous day!
# MEDP Exception No intraday(minute interval) data for previous day!
# PRTK Exception No intraday(minute interval) data for previous day!
# ACRE Exception Less than 200 Data points for today (186), skipping!
# JOBS Exception No intraday(minute interval) data for previous day!
# DIOD Exception No intraday(minute interval) data for previous day!
# 701 2192 2020-11-30
# EVV Exception No intraday(minute interval) data for previous day!
# PRTH Exception No intraday(minute interval) data for previous day!
# SHYF Exception No intraday(minute interval) data for previous day!
# MMYT Exception Less than 200 Data points for today (199), skipping!
# NVRO Exception No intraday(minute interval) data for previous day!
# SMMC Exception No intraday(minute interval) data for previous day!
# PAE Exception No intraday(minute interval) data for previous day!
# SWX Exception No intraday(minute interval) data for previous day!
# ACMR Exception No intraday(minute interval) data for previous day!
# CWST Exception No intraday(minute interval) data for previous day!
# OPES Exception No intraday(minute interval) data for previous day!
# CUE Exception No intraday(minute interval) data for previous day!
# XENT Exception No intraday(minute interval) data for previous day!
# 801 2192 2020-11-30
# CLH Exception No intraday(minute interval) data for previous day!
# USX Exception Less than 200 Data points for today (194), skipping!
# CTT Exception No intraday(minute interval) data for previous day!
# TSLX Exception No intraday(minute interval) data for previous day!
# GTT Exception No intraday(minute interval) data for previous day!
# COHR Exception No intraday(minute interval) data for previous day!
# ETY Exception No intraday(minute interval) data for previous day!
# LIVN Exception Less than 200 Data points for today (197), skipping!
# DRTT Exception No intraday(minute interval) data for previous day!
# ALDX Exception No intraday(minute interval) data for previous day!
# NOAH Exception No intraday(minute interval) data for previous day!
# RETO Exception No intraday(minute interval) data for previous day!
# TPTX Exception No intraday(minute interval) data for previous day!
# LNTH Exception No intraday(minute interval) data for previous day!
# UFPI Exception No intraday(minute interval) data for previous day!
# FPI Exception No intraday(minute interval) data for previous day!
# VRTU Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# BRG Exception No intraday(minute interval) data for previous day!
# PCTY Exception No intraday(minute interval) data for previous day!
# 901 2192 2020-11-30
# AGTC Exception Less than 200 Data points for today (181), skipping!
# LII Exception No intraday(minute interval) data for previous day!
# COHU Exception No intraday(minute interval) data for previous day!
# NTGR Exception No intraday(minute interval) data for previous day!
# PRGS Exception No intraday(minute interval) data for previous day!
# CSL Exception No intraday(minute interval) data for previous day!
# OLED Exception No intraday(minute interval) data for previous day!
# VCRA Exception No intraday(minute interval) data for previous day!
# IMV Exception No intraday(minute interval) data for previous day!
# BCSF Exception No intraday(minute interval) data for previous day!
# EPAY Exception Less than 200 Data points for today (170), skipping!
# 1001 2192 2020-11-30
# CMD Exception No intraday(minute interval) data for previous day!
# CHH Exception No intraday(minute interval) data for previous day!
# BDTX Exception No intraday(minute interval) data for previous day!
# BRP Exception No intraday(minute interval) data for previous day!
# ICLR Exception No intraday(minute interval) data for previous day!
# CASY Exception No intraday(minute interval) data for previous day!
# PAR Exception No intraday(minute interval) data for previous day!
# RDUS Exception No intraday(minute interval) data for previous day!
# 1101 2192 2020-11-30
# CMCM Exception No intraday(minute interval) data for previous day!
# GLYC Exception No intraday(minute interval) data for previous day!
# DLX Exception No intraday(minute interval) data for previous day!
# GIM Exception No intraday(minute interval) data for previous day!
# BCOR Exception No intraday(minute interval) data for previous day!
# MOH Exception No intraday(minute interval) data for previous day!
# ENIC Exception No intraday(minute interval) data for previous day!
# ANAB Exception No intraday(minute interval) data for previous day!
# CVBF Exception No intraday(minute interval) data for previous day!
# HMSY Exception No intraday(minute interval) data for previous day!
# TRST Exception No intraday(minute interval) data for previous day!
# ALNA Exception No intraday(minute interval) data for previous day!
# OEC Exception No intraday(minute interval) data for previous day!
# MHO Exception No intraday(minute interval) data for previous day!
# DSL Exception No intraday(minute interval) data for previous day!
# MWK Exception No intraday(minute interval) data for previous day!
# GWW Exception No intraday(minute interval) data for previous day!
# TWI Exception No intraday(minute interval) data for previous day!
# NSTG Exception No intraday(minute interval) data for previous day!
# MSGS Exception No intraday(minute interval) data for previous day!
# ETJ Exception No intraday(minute interval) data for previous day!
# UTHR Exception No intraday(minute interval) data for previous day!
# AQST Exception No intraday(minute interval) data for previous day!
# 1201 2192 2020-11-30
# AFYA Exception No intraday(minute interval) data for previous day!
# REYN Exception No intraday(minute interval) data for previous day!
# LGIH Exception No intraday(minute interval) data for previous day!
# MBRX Exception No intraday(minute interval) data for previous day!
# BWXT Exception No intraday(minute interval) data for previous day!
# COR Exception No intraday(minute interval) data for previous day!
# MMSI Exception Less than 200 Data points for today (195), skipping!
# LOCO Exception No intraday(minute interval) data for previous day!
# KLR Exception No intraday(minute interval) data for previous day!
# PFLT Exception No intraday(minute interval) data for previous day!
# KRP Exception No intraday(minute interval) data for previous day!
# FTK Exception Less than 200 Data points for today (185), skipping!
# ALSK Exception No intraday(minute interval) data for previous day!
# DSGX Exception No intraday(minute interval) data for previous day!
# 1301 2192 2020-11-30
# OCX Exception No intraday(minute interval) data for previous day!
# BFAM Exception No intraday(minute interval) data for previous day!
# IDA Exception No intraday(minute interval) data for previous day!
# CKPT Exception No intraday(minute interval) data for previous day!
# HFRO Exception No intraday(minute interval) data for previous day!
# JPS Exception No intraday(minute interval) data for previous day!
# GEOS Exception No intraday(minute interval) data for previous day!
# LIZI Exception No intraday(minute interval) data for previous day!
# ETTX Exception No intraday(minute interval) data for previous day!
# CLNC Exception Less than 200 Data points for today (191), skipping!
# SBBP Exception Less than 200 Data points for today (190), skipping!
# ALTR Exception No intraday(minute interval) data for previous day!
# TTEK Exception Less than 200 Data points for today (191), skipping!
# 1401 2192 2020-11-30
# MOHO Exception Less than 200 Data points for today (180), skipping!
# PI Exception No intraday(minute interval) data for previous day!
# CCMP Exception No intraday(minute interval) data for previous day!
# PSO Exception No intraday(minute interval) data for previous day!
# DPG Exception No intraday(minute interval) data for previous day!
# ONE Exception No intraday(minute interval) data for previous day!
# IGR Exception No intraday(minute interval) data for previous day!
# WNC Exception No intraday(minute interval) data for previous day!
# BBN Exception No intraday(minute interval) data for previous day!
# BBAR Exception No intraday(minute interval) data for previous day!
# SPXC Exception No intraday(minute interval) data for previous day!
# CSII Exception No intraday(minute interval) data for previous day!
# NEOS Exception No intraday(minute interval) data for previous day!
# 1501 2192 2020-11-30
# STRA Exception No intraday(minute interval) data for previous day!
# TCPC Exception No intraday(minute interval) data for previous day!
# SFNC Exception Less than 200 Data points for today (194), skipping!
# EGOV Exception No intraday(minute interval) data for previous day!
# BDC Exception No intraday(minute interval) data for previous day!
# NXE Exception No intraday(minute interval) data for previous day!
# ACA Exception No intraday(minute interval) data for previous day!
# AMPH Exception No intraday(minute interval) data for previous day!
# SD Exception No intraday(minute interval) data for previous day!
# PAVM Exception Less than 200 Data points for today (191), skipping!
# GOLF Exception No intraday(minute interval) data for previous day!
# FDS Exception No intraday(minute interval) data for previous day!
# DSX Exception No intraday(minute interval) data for previous day!
# MNRO Exception No intraday(minute interval) data for previous day!
# GPI Exception No intraday(minute interval) data for previous day!
# LCI Exception No intraday(minute interval) data for previous day!
# BLD Exception Less than 200 Data points for today (178), skipping!
# BV Exception No intraday(minute interval) data for previous day!
# 1601 2192 2020-11-30
# NTEC Exception No intraday(minute interval) data for previous day!
# SAIA Exception No intraday(minute interval) data for previous day!
# FAMI Exception Less than 200 Data points for today (146), skipping!
# SIMO Exception Less than 200 Data points for today (173), skipping!
# ABG Exception No intraday(minute interval) data for previous day!
# NXTC Exception No intraday(minute interval) data for previous day!
# CRL Exception No intraday(minute interval) data for previous day!
# FOCS Exception No intraday(minute interval) data for previous day!
# VAC Exception No intraday(minute interval) data for previous day!
# FUL Exception No intraday(minute interval) data for previous day!
# ATHE Exception No intraday(minute interval) data for previous day!
# BEAT Exception No intraday(minute interval) data for previous day!
# GLOP Exception No intraday(minute interval) data for previous day!
# TLYS Exception No intraday(minute interval) data for previous day!
# NSCO Exception No intraday(minute interval) data for previous day!
# OSW Exception No intraday(minute interval) data for previous day!
# AEHR Exception No intraday(minute interval) data for previous day!
# 1701 2192 2020-11-30
# HHC Exception No intraday(minute interval) data for previous day!
# MC Exception No intraday(minute interval) data for previous day!
# NAOV Exception No intraday(minute interval) data for previous day!
# EPAM Exception No intraday(minute interval) data for previous day!
# WHD Exception No intraday(minute interval) data for previous day!
# PTCT Exception No intraday(minute interval) data for previous day!
# HCHC Exception No intraday(minute interval) data for previous day!
# ENSG Exception No intraday(minute interval) data for previous day!
# RETA Exception No intraday(minute interval) data for previous day!
# AESE Exception No intraday(minute interval) data for previous day!
# HAE Exception No intraday(minute interval) data for previous day!
# AVNS Exception No intraday(minute interval) data for previous day!
# NEA Exception No intraday(minute interval) data for previous day!
# COLM Exception No intraday(minute interval) data for previous day!
# FFIN Exception No intraday(minute interval) data for previous day!
# KTOV Exception No intraday(minute interval) data for previous day!
# BHLB Exception No intraday(minute interval) data for previous day!
# LMPX Exception No intraday(minute interval) data for previous day!
# KRNT Exception No intraday(minute interval) data for previous day!
# TNAV Exception No intraday(minute interval) data for previous day!
# 1801 2192 2020-11-30
# CMRX Exception No intraday(minute interval) data for previous day!
# HCCH Exception No intraday(minute interval) data for previous day!
# LITB Exception Less than 200 Data points for today (189), skipping!
# CCS Exception No intraday(minute interval) data for previous day!
# GEN Exception Less than 200 Data points for today (189), skipping!
# CQP Exception No intraday(minute interval) data for previous day!
# PBH Exception No intraday(minute interval) data for previous day!
# EIG Exception No intraday(minute interval) data for previous day!
# MANH Exception No intraday(minute interval) data for previous day!
# SRGA Exception No intraday(minute interval) data for previous day!
# 1901 2192 2020-11-30
# LEGN Exception No intraday(minute interval) data for previous day!
# HDSN Exception No intraday(minute interval) data for previous day!
# ANGO Exception Less than 200 Data points for today (190), skipping!
# BXMX Exception No intraday(minute interval) data for previous day!
# PROG Exception No intraday(minute interval) data for previous day!
# BCC Exception No intraday(minute interval) data for previous day!
# 2001 2192 2020-11-30
# UPLD Exception Less than 200 Data points for today (196), skipping!
# INSP Exception No intraday(minute interval) data for previous day!
# HCAT Exception No intraday(minute interval) data for previous day!
# FMTX Exception No intraday(minute interval) data for previous day!
# IMXI Exception No intraday(minute interval) data for previous day!
# SOGO Exception No intraday(minute interval) data for previous day!
# AXSM Exception No intraday(minute interval) data for previous day!
# CRTX Exception No intraday(minute interval) data for previous day!
# AXAS Exception No intraday(minute interval) data for previous day!
# LAD Exception No intraday(minute interval) data for previous day!
# GRIL Exception No intraday(minute interval) data for previous day!
# LOAK Exception No intraday(minute interval) data for previous day!
# NOVS Exception No intraday(minute interval) data for previous day!
# GLOB Exception No intraday(minute interval) data for previous day!
# AX Exception No intraday(minute interval) data for previous day!
# PLYM Exception No intraday(minute interval) data for previous day!
# WSFS Exception No intraday(minute interval) data for previous day!
# 2101 2192 2020-11-30
# AWH Exception No intraday(minute interval) data for previous day!
# PAYC Exception No intraday(minute interval) data for previous day!
# KRA Exception No intraday(minute interval) data for previous day!
# VNDA Exception No intraday(minute interval) data for previous day!
# VBTX Exception No intraday(minute interval) data for previous day!
# CLLS Exception No intraday(minute interval) data for previous day!
# DNLI Exception No intraday(minute interval) data for previous day!
# BL Exception No intraday(minute interval) data for previous day!
# SLRX Exception No intraday(minute interval) data for previous day!
# SIVB Exception No intraday(minute interval) data for previous day!
# NFG Exception No intraday(minute interval) data for previous day!
# CSU Exception No intraday(minute interval) data for previous day!
# SEM Exception No intraday(minute interval) data for previous day!
# NVR Exception No intraday(minute interval) data for previous day!
# INVA Exception No intraday(minute interval) data for previous day!
# RC Exception No intraday(minute interval) data for previous day!
# SYRS Exception No intraday(minute interval) data for previous day!
# PB Exception No intraday(minute interval) data for previous day!
# RBC Exception No intraday(minute interval) data for previous day!
# TCRR Exception No intraday(minute interval) data for previous day!
# ORN Exception No intraday(minute interval) data for previous day!
# USAT Exception No intraday(minute interval) data for previous day!
# POWW Exception No intraday(minute interval) data for previous day!
# 1 2192 2020-12-01
# SOI Exception Less than 200 Data points for today (188), skipping!
# CASA Exception Less than 200 Data points for today (184), skipping!
# VC Exception Less than 200 Data points for today (193), skipping!
# 101 2192 2020-12-01
# CLDT Exception Less than 200 Data points for today (191), skipping!
# MESO Exception Less than 200 Data points for today (179), skipping!
# TYME Exception Less than 200 Data points for today (151), skipping!
# CGBD Exception Less than 200 Data points for today (185), skipping!
# 201 2192 2020-12-01
# ENZ Exception Less than 200 Data points for today (190), skipping!
# MTLS Exception Less than 200 Data points for today (167), skipping!
# 301 2192 2020-12-01
# OXSQ Exception Less than 200 Data points for today (166), skipping!
# ROAD Exception Less than 200 Data points for today (159), skipping!
# PRIM Exception Less than 200 Data points for today (190), skipping!
# GOOD Exception Less than 200 Data points for today (199), skipping!
# SPNS Exception Less than 200 Data points for today (190), skipping!
# 401 2192 2020-12-01
# FRPT Exception Less than 200 Data points for today (199), skipping!
# KIDS Exception Less than 200 Data points for today (163), skipping!
# VNTR Exception Less than 200 Data points for today (182), skipping!
# ADTN Exception Less than 200 Data points for today (196), skipping!
# VTVT Exception Less than 200 Data points for today (192), skipping!
# JFIN Exception Less than 200 Data points for today (181), skipping!
# ETW Exception Less than 200 Data points for today (155), skipping!
# 501 2192 2020-12-01
# TG Exception Less than 200 Data points for today (121), skipping!
# CYCN Exception Less than 200 Data points for today (192), skipping!
# FEI Exception Less than 200 Data points for today (198), skipping!
# 601 2192 2020-12-01
# MSGE Exception Less than 200 Data points for today (197), skipping!
# CENTA Exception Less than 200 Data points for today (199), skipping!
# UTG Exception Less than 200 Data points for today (188), skipping!
# 701 2192 2020-12-01
# 801 2192 2020-12-01
# RETO Exception Less than 200 Data points for today (95), skipping!
# VTA Exception Less than 200 Data points for today (199), skipping!
# 901 2192 2020-12-01
# AVID Exception Less than 200 Data points for today (187), skipping!
# UAMY Exception Less than 200 Data points for today (198), skipping!
# IMV Exception Less than 200 Data points for today (189), skipping!
# DHF Exception Less than 200 Data points for today (154), skipping!
# BCSF Exception Less than 200 Data points for today (154), skipping!
# EPAY Exception Less than 200 Data points for today (195), skipping!
# 1001 2192 2020-12-01
# CHH Exception Less than 200 Data points for today (193), skipping!
# 1101 2192 2020-12-01
# MWK Exception Less than 200 Data points for today (120), skipping!
# TWI Exception Less than 200 Data points for today (178), skipping!
# ETJ Exception Less than 200 Data points for today (180), skipping!
# 1201 2192 2020-12-01
# FTK Exception Less than 200 Data points for today (184), skipping!
# 1301 2192 2020-12-01
# LIZI Exception Less than 200 Data points for today (129), skipping!
# CLNC Exception Less than 200 Data points for today (196), skipping!
# 1401 2192 2020-12-01
# BBN Exception Less than 200 Data points for today (187), skipping!
# 1501 2192 2020-12-01
# TCPC Exception Less than 200 Data points for today (159), skipping!
# NXE Exception Less than 200 Data points for today (143), skipping!
# SD Exception Less than 200 Data points for today (199), skipping!
# DSX Exception Less than 200 Data points for today (190), skipping!
# BV Exception Less than 200 Data points for today (191), skipping!
# 1601 2192 2020-12-01
# NTEC Exception Less than 200 Data points for today (106), skipping!
# LAZ Exception Less than 200 Data points for today (191), skipping!
# NSCO Exception Less than 200 Data points for today (28), skipping!
# AEHR Exception Less than 200 Data points for today (81), skipping!
# 1701 2192 2020-12-01
# HUSA Exception Less than 200 Data points for today (122), skipping!
# AESE Exception Less than 200 Data points for today (195), skipping!
# AVNS Exception Less than 200 Data points for today (197), skipping!
# NEA Exception Less than 200 Data points for today (181), skipping!
# LMPX Exception Less than 200 Data points for today (191), skipping!
# 1801 2192 2020-12-01
# HCCH Exception Less than 200 Data points for today (126), skipping!
# CQP Exception Less than 200 Data points for today (142), skipping!
# 1901 2192 2020-12-01
# LEGN Exception Less than 200 Data points for today (169), skipping!
# TBBK Exception Less than 200 Data points for today (199), skipping!
# VERX Exception Less than 200 Data points for today (173), skipping!
# BXMX Exception Less than 200 Data points for today (182), skipping!
# CVGI Exception Less than 200 Data points for today (157), skipping!
# 2001 2192 2020-12-01
# SOAC Exception Less than 200 Data points for today (192), skipping!
# IMXI Exception Less than 200 Data points for today (176), skipping!
# CRTX Exception Less than 200 Data points for today (135), skipping!
# GLOB Exception Less than 200 Data points for today (194), skipping!
# 2101 2192 2020-12-01
# SLRX Exception Less than 200 Data points for today (169), skipping!
# CSU Exception Less than 200 Data points for today (101), skipping!
# DSSI Exception Less than 200 Data points for today (173), skipping!
# ORN Exception Less than 200 Data points for today (180), skipping!
# MDXG Exception Less than 200 Data points for today (197), skipping!
# 1 2192 2020-12-02
# EXPO Exception Less than 200 Data points for today (160), skipping!
# FFBC Exception Less than 200 Data points for today (195), skipping!
# SOI Exception Less than 200 Data points for today (176), skipping!
# UBA Exception Less than 200 Data points for today (195), skipping!
# STC Exception Less than 200 Data points for today (197), skipping!
# HONE Exception Less than 200 Data points for today (199), skipping!
# PNNT Exception Less than 200 Data points for today (195), skipping!
# 101 2192 2020-12-02
# ENV Exception Less than 200 Data points for today (190), skipping!
# TRNO Exception Less than 200 Data points for today (184), skipping!
# TRHC Exception Less than 200 Data points for today (196), skipping!
# CLDT Exception Less than 200 Data points for today (191), skipping!
# TYME Exception Less than 200 Data points for today (138), skipping!
# CGBD Exception Less than 200 Data points for today (190), skipping!
# LOPE Exception Less than 200 Data points for today (196), skipping!
# SPH Exception Less than 200 Data points for today (189), skipping!
# MEI Exception Less than 200 Data points for today (185), skipping!
# BIMI Exception Less than 200 Data points for today (136), skipping!
# 201 2192 2020-12-02
# ENZ Exception Less than 200 Data points for today (168), skipping!
# VRS Exception Less than 200 Data points for today (157), skipping!
# ATOM Exception Less than 200 Data points for today (175), skipping!
# DESP Exception Less than 200 Data points for today (173), skipping!
# AVCO Exception Less than 200 Data points for today (161), skipping!
# XLRN Exception Less than 200 Data points for today (180), skipping!
# WOR Exception Less than 200 Data points for today (189), skipping!
# MTLS Exception Less than 200 Data points for today (182), skipping!
# FIBK Exception Less than 200 Data points for today (179), skipping!
# KBAL Exception Less than 200 Data points for today (191), skipping!
# ASRT Exception Less than 200 Data points for today (188), skipping!
# 301 2192 2020-12-02
# PTGX Exception Less than 200 Data points for today (170), skipping!
# DAVA Exception Less than 200 Data points for today (199), skipping!
# SCOR Exception Less than 200 Data points for today (153), skipping!
# OSMT Exception Less than 200 Data points for today (159), skipping!
# KOF Exception Less than 200 Data points for today (178), skipping!
# 401 2192 2020-12-02
# VNTR Exception Less than 200 Data points for today (196), skipping!
# ADTN Exception Less than 200 Data points for today (152), skipping!
# JFIN Exception Less than 200 Data points for today (157), skipping!
# EVR Exception Less than 200 Data points for today (177), skipping!
# HTGM Exception Less than 200 Data points for today (150), skipping!
# NINE Exception Less than 200 Data points for today (153), skipping!
# 501 2192 2020-12-02
# NDSN Exception Less than 200 Data points for today (172), skipping!
# ABM Exception Less than 200 Data points for today (181), skipping!
# 601 2192 2020-12-02
# WVE Exception Less than 200 Data points for today (180), skipping!
# MASI Exception Less than 200 Data points for today (151), skipping!
# BVXV Exception Less than 200 Data points for today (152), skipping!
# BNFT Exception Less than 200 Data points for today (153), skipping!
# MSGE Exception Less than 200 Data points for today (158), skipping!
# CENTA Exception Less than 200 Data points for today (183), skipping!
# UTG Exception Less than 200 Data points for today (168), skipping!
# DIOD Exception Less than 200 Data points for today (195), skipping!
# 701 2192 2020-12-02
# PRTH Exception Less than 200 Data points for today (164), skipping!
# SHYF Exception Less than 200 Data points for today (183), skipping!
# NVRO Exception Less than 200 Data points for today (183), skipping!
# GRA Exception Less than 200 Data points for today (191), skipping!
# TITN Exception Less than 200 Data points for today (192), skipping!
# ALRN Exception Less than 200 Data points for today (186), skipping!
# CDXS Exception Less than 200 Data points for today (116), skipping!
# EIGR Exception Less than 200 Data points for today (199), skipping!
# OPES Exception Less than 200 Data points for today (199), skipping!
# CUE Exception Less than 200 Data points for today (183), skipping!
# 801 2192 2020-12-02
# CTT Exception Less than 200 Data points for today (195), skipping!
# TACO Exception Less than 200 Data points for today (188), skipping!
# VVR Exception Less than 200 Data points for today (145), skipping!
# TPTX Exception Less than 200 Data points for today (197), skipping!
# ENVA Exception Less than 200 Data points for today (170), skipping!
# SMCI Exception Less than 200 Data points for today (194), skipping!
# VRTU Exception Less than 200 Data points for today (192), skipping!
# 901 2192 2020-12-02
# HZO Exception Less than 200 Data points for today (197), skipping!
# ITRI Exception Less than 200 Data points for today (184), skipping!
# PRGS Exception Less than 200 Data points for today (180), skipping!
# ZKIN Exception Less than 200 Data points for today (199), skipping!
# OLED Exception Less than 200 Data points for today (158), skipping!
# UAMY Exception Less than 200 Data points for today (181), skipping!
# IMV Exception Less than 200 Data points for today (170), skipping!
# BCSF Exception Less than 200 Data points for today (183), skipping!
# 1001 2192 2020-12-02
# ADIL Exception Less than 200 Data points for today (129), skipping!
# AMN Exception Less than 200 Data points for today (197), skipping!
# CHH Exception Less than 200 Data points for today (144), skipping!
# AVEO Exception Less than 200 Data points for today (168), skipping!
# BRP Exception Less than 200 Data points for today (140), skipping!
# AFIN Exception Less than 200 Data points for today (184), skipping!
# INFI Exception Less than 200 Data points for today (188), skipping!
# PAR Exception Less than 200 Data points for today (167), skipping!
# RDUS Exception Less than 200 Data points for today (185), skipping!
# 1101 2192 2020-12-02
# MOH Exception Less than 200 Data points for today (184), skipping!
# OEC Exception Less than 200 Data points for today (183), skipping!
# TWI Exception Less than 200 Data points for today (181), skipping!
# 1201 2192 2020-12-02
# AFYA Exception Less than 200 Data points for today (184), skipping!
# DSKE Exception Less than 200 Data points for today (191), skipping!
# BSMX Exception Less than 200 Data points for today (176), skipping!
# RVT Exception Less than 200 Data points for today (188), skipping!
# FTK Exception Less than 200 Data points for today (190), skipping!
# 1301 2192 2020-12-02
# SILK Exception Less than 200 Data points for today (181), skipping!
# LIZI Exception Less than 200 Data points for today (147), skipping!
# SBBP Exception Less than 200 Data points for today (185), skipping!
# ALTR Exception Less than 200 Data points for today (164), skipping!
# 1401 2192 2020-12-02
# CCMP Exception Less than 200 Data points for today (173), skipping!
# CTB Exception Less than 200 Data points for today (194), skipping!
# ONE Exception Less than 200 Data points for today (184), skipping!
# LPTX Exception Less than 200 Data points for today (146), skipping!
# BSIG Exception Less than 200 Data points for today (153), skipping!
# ARDX Exception Less than 200 Data points for today (185), skipping!
# SPXC Exception Less than 200 Data points for today (186), skipping!
# NEOS Exception Less than 200 Data points for today (190), skipping!
# 1501 2192 2020-12-02
# AAT Exception Less than 200 Data points for today (199), skipping!
# TCPC Exception Less than 200 Data points for today (185), skipping!
# SFNC Exception Less than 200 Data points for today (167), skipping!
# NXE Exception Less than 200 Data points for today (187), skipping!
# ACA Exception Less than 200 Data points for today (195), skipping!
# AMPH Exception Less than 200 Data points for today (180), skipping!
# SD Exception Less than 200 Data points for today (195), skipping!
# DSX Exception Less than 200 Data points for today (123), skipping!
# MNRO Exception Less than 200 Data points for today (195), skipping!
# LCI Exception Less than 200 Data points for today (182), skipping!
# BLD Exception Less than 200 Data points for today (195), skipping!
# COLB Exception Less than 200 Data points for today (178), skipping!
# 1601 2192 2020-12-02
# FAMI Exception Less than 200 Data points for today (181), skipping!
# VAC Exception Less than 200 Data points for today (183), skipping!
# NSCO Exception Less than 200 Data points for today (33), skipping!
# AEHR Exception Less than 200 Data points for today (52), skipping!
# 1701 2192 2020-12-02
# LORL Exception Less than 200 Data points for today (193), skipping!
# WHD Exception Less than 200 Data points for today (182), skipping!
# PTCT Exception Less than 200 Data points for today (193), skipping!
# HCHC Exception Less than 200 Data points for today (183), skipping!
# ENSG Exception Less than 200 Data points for today (198), skipping!
# AESE Exception Less than 200 Data points for today (169), skipping!
# HAE Exception Less than 200 Data points for today (174), skipping!
# NEA Exception Less than 200 Data points for today (171), skipping!
# KTOV Exception Less than 200 Data points for today (195), skipping!
# TNAV Exception Less than 200 Data points for today (177), skipping!
# 1801 2192 2020-12-02
# HCCH Exception Less than 200 Data points for today (154), skipping!
# LITB Exception Less than 200 Data points for today (153), skipping!
# CCS Exception Less than 200 Data points for today (197), skipping!
# CQP Exception Less than 200 Data points for today (167), skipping!
# VIOT Exception Less than 200 Data points for today (194), skipping!
# MANH Exception Less than 200 Data points for today (193), skipping!
# ADTX Exception Less than 200 Data points for today (173), skipping!
# 1901 2192 2020-12-02
# SEEL Exception Less than 200 Data points for today (196), skipping!
# FOXF Exception Less than 200 Data points for today (165), skipping!
# ATGE Exception Less than 200 Data points for today (198), skipping!
# BTBT Exception Less than 200 Data points for today (189), skipping!
# BXMX Exception Less than 200 Data points for today (152), skipping!
# CVGI Exception Less than 200 Data points for today (187), skipping!
# ISEE Exception Less than 200 Data points for today (185), skipping!
# FIXX Exception Less than 200 Data points for today (192), skipping!
# SXT Exception Less than 200 Data points for today (164), skipping!
# 2001 2192 2020-12-02
# BHAT Exception Less than 200 Data points for today (157), skipping!
# HYT Exception Less than 200 Data points for today (156), skipping!
# GHIV Exception Less than 200 Data points for today (186), skipping!
# CRTX Exception Less than 200 Data points for today (189), skipping!
# GRIL Exception Less than 200 Data points for today (169), skipping!
# NOVS Exception Less than 200 Data points for today (158), skipping!
# PLYM Exception Less than 200 Data points for today (166), skipping!
# 2101 2192 2020-12-02
# VBTX Exception Less than 200 Data points for today (159), skipping!
# CLLS Exception Less than 200 Data points for today (188), skipping!
# SLRX Exception Less than 200 Data points for today (148), skipping!
# DSSI Exception Less than 200 Data points for today (158), skipping!
# NVR Exception Less than 200 Data points for today (194), skipping!
# DHY Exception Less than 200 Data points for today (181), skipping!
# RC Exception Less than 200 Data points for today (179), skipping!
# TCRR Exception Less than 200 Data points for today (185), skipping!
# ORN Exception Less than 200 Data points for today (147), skipping!
# POWW Exception Less than 200 Data points for today (186), skipping!
# 1 2192 2020-12-03
# WSR Exception Less than 200 Data points for today (191), skipping!
# WAFD Exception Less than 200 Data points for today (173), skipping!
# SOI Exception Less than 200 Data points for today (189), skipping!
# DOOR Exception Less than 200 Data points for today (143), skipping!
# STSA Exception Less than 200 Data points for today (187), skipping!
# UBA Exception Less than 200 Data points for today (199), skipping!
# HONE Exception Less than 200 Data points for today (180), skipping!
# AIHS Exception Less than 200 Data points for today (186), skipping!
# VRNT Exception Less than 200 Data points for today (198), skipping!
# CACC Exception Less than 200 Data points for today (160), skipping!
# 101 2192 2020-12-03
# ENV Exception Less than 200 Data points for today (192), skipping!
# HYRE Exception Less than 200 Data points for today (187), skipping!
# TRNO Exception Less than 200 Data points for today (174), skipping!
# DTEA Exception Less than 200 Data points for today (125), skipping!
# MESO Exception Less than 200 Data points for today (164), skipping!
# LOPE Exception Less than 200 Data points for today (199), skipping!
# SPH Exception Less than 200 Data points for today (190), skipping!
# 201 2192 2020-12-03
# LPG Exception Less than 200 Data points for today (187), skipping!
# ENZ Exception Less than 200 Data points for today (178), skipping!
# VRS Exception Less than 200 Data points for today (167), skipping!
# ATOM Exception Less than 200 Data points for today (187), skipping!
# TFX Exception Less than 200 Data points for today (186), skipping!
# AVCO Exception Less than 200 Data points for today (152), skipping!
# WOR Exception Less than 200 Data points for today (177), skipping!
# APOG Exception Less than 200 Data points for today (151), skipping!
# FIBK Exception Less than 200 Data points for today (177), skipping!
# AMRC Exception Less than 200 Data points for today (184), skipping!
# 301 2192 2020-12-03
# XNCR Exception Less than 200 Data points for today (168), skipping!
# AGLE Exception Less than 200 Data points for today (155), skipping!
# MSCI Exception Less than 200 Data points for today (197), skipping!
# SYBX Exception Less than 200 Data points for today (191), skipping!
# SCOR Exception Less than 200 Data points for today (176), skipping!
# OSMT Exception Less than 200 Data points for today (166), skipping!
# IPGP Exception Less than 200 Data points for today (126), skipping!
# 401 2192 2020-12-03
# VNTR Exception Less than 200 Data points for today (180), skipping!
# CNNE Exception Less than 200 Data points for today (195), skipping!
# VTVT Exception Less than 200 Data points for today (196), skipping!
# HTGM Exception Less than 200 Data points for today (159), skipping!
# GWB Exception Less than 200 Data points for today (182), skipping!
# 501 2192 2020-12-03
# ABMD Exception Less than 200 Data points for today (170), skipping!
# BPMP Exception Less than 200 Data points for today (168), skipping!
# NDSN Exception Less than 200 Data points for today (189), skipping!
# ALEX Exception Less than 200 Data points for today (153), skipping!
# SOHU Exception Less than 200 Data points for today (178), skipping!
# NWE Exception Less than 200 Data points for today (182), skipping!
# 601 2192 2020-12-03
# GBX Exception Less than 200 Data points for today (198), skipping!
# BVXV Exception Less than 200 Data points for today (191), skipping!
# MSGE Exception Less than 200 Data points for today (166), skipping!
# LAND Exception Less than 200 Data points for today (194), skipping!
# CENTA Exception Less than 200 Data points for today (189), skipping!
# FOE Exception Less than 200 Data points for today (150), skipping!
# MEDP Exception Less than 200 Data points for today (187), skipping!
# DIOD Exception Less than 200 Data points for today (122), skipping!
# 701 2192 2020-12-03
# GVA Exception Less than 200 Data points for today (181), skipping!
# SMMC Exception Less than 200 Data points for today (126), skipping!
# SUPV Exception Less than 200 Data points for today (144), skipping!
# PAE Exception Less than 200 Data points for today (172), skipping!
# ACMR Exception Less than 200 Data points for today (191), skipping!
# CWST Exception Less than 200 Data points for today (197), skipping!
# OPES Exception Less than 200 Data points for today (177), skipping!
# ORGO Exception Less than 200 Data points for today (167), skipping!
# 801 2192 2020-12-03
# HEP Exception Less than 200 Data points for today (180), skipping!
# HUBB Exception Less than 200 Data points for today (199), skipping!
# DRTT Exception Less than 200 Data points for today (191), skipping!
# VVR Exception Less than 200 Data points for today (182), skipping!
# NOAH Exception Less than 200 Data points for today (142), skipping!
# RETO Exception Less than 200 Data points for today (124), skipping!
# LNTH Exception Less than 200 Data points for today (174), skipping!
# UFPI Exception Less than 200 Data points for today (169), skipping!
# ENVA Exception Less than 200 Data points for today (164), skipping!
# FPI Exception Less than 200 Data points for today (166), skipping!
# SMCI Exception Less than 200 Data points for today (172), skipping!
# NGHC Exception Less than 200 Data points for today (193), skipping!
# BRG Exception Less than 200 Data points for today (132), skipping!
# VTA Exception Less than 200 Data points for today (188), skipping!
# 901 2192 2020-12-03
# HZO Exception Less than 200 Data points for today (179), skipping!
# AQMS Exception Less than 200 Data points for today (148), skipping!
# LII Exception Less than 200 Data points for today (198), skipping!
# NTGR Exception Less than 200 Data points for today (186), skipping!
# ITRI Exception Less than 200 Data points for today (171), skipping!
# PRGS Exception Less than 200 Data points for today (192), skipping!
# ZKIN Exception Less than 200 Data points for today (157), skipping!
# VCRA Exception Less than 200 Data points for today (188), skipping!
# LAKE Exception Less than 200 Data points for today (156), skipping!
# DHF Exception Less than 200 Data points for today (134), skipping!
# EPAY Exception Less than 200 Data points for today (195), skipping!
# 1001 2192 2020-12-03
# CMD Exception Less than 200 Data points for today (180), skipping!
# ADIL Exception Less than 200 Data points for today (127), skipping!
# CHH Exception Less than 200 Data points for today (171), skipping!
# TM Exception Less than 200 Data points for today (199), skipping!
# BRP Exception Less than 200 Data points for today (164), skipping!
# AFIN Exception Less than 200 Data points for today (195), skipping!
# PAR Exception Less than 200 Data points for today (191), skipping!
# RDUS Exception Less than 200 Data points for today (170), skipping!
# 1101 2192 2020-12-03
# CMCM Exception Less than 200 Data points for today (146), skipping!
# DLX Exception Less than 200 Data points for today (145), skipping!
# GIM Exception Less than 200 Data points for today (187), skipping!
# BCOR Exception Less than 200 Data points for today (190), skipping!
# ANAB Exception Less than 200 Data points for today (186), skipping!
# CVBF Exception Less than 200 Data points for today (175), skipping!
# TRST Exception Less than 200 Data points for today (149), skipping!
# TWI Exception Less than 200 Data points for today (154), skipping!
# MSGS Exception Less than 200 Data points for today (167), skipping!
# 1201 2192 2020-12-03
# DSKE Exception Less than 200 Data points for today (181), skipping!
# BSMX Exception Less than 200 Data points for today (174), skipping!
# RVT Exception Less than 200 Data points for today (194), skipping!
# BRY Exception Less than 200 Data points for today (156), skipping!
# 1301 2192 2020-12-03
# OCX Exception Less than 200 Data points for today (176), skipping!
# JPS Exception Less than 200 Data points for today (174), skipping!
# TCBI Exception Less than 200 Data points for today (182), skipping!
# CLNC Exception Less than 200 Data points for today (194), skipping!
# ALTR Exception Less than 200 Data points for today (174), skipping!
# 1401 2192 2020-12-03
# CTB Exception Less than 200 Data points for today (159), skipping!
# PSO Exception Less than 200 Data points for today (163), skipping!
# POWI Exception Less than 200 Data points for today (188), skipping!
# ACRS Exception Less than 200 Data points for today (149), skipping!
# WNC Exception Less than 200 Data points for today (199), skipping!
# HMI Exception Less than 200 Data points for today (197), skipping!
# ARDX Exception Less than 200 Data points for today (187), skipping!
# SPXC Exception Less than 200 Data points for today (166), skipping!
# CSII Exception Less than 200 Data points for today (160), skipping!
# NEOS Exception Less than 200 Data points for today (142), skipping!
# 1501 2192 2020-12-03
# GTLS Exception Less than 200 Data points for today (179), skipping!
# STRA Exception Less than 200 Data points for today (180), skipping!
# TCPC Exception Less than 200 Data points for today (190), skipping!
# SFNC Exception Less than 200 Data points for today (190), skipping!
# EGOV Exception Less than 200 Data points for today (163), skipping!
# BDC Exception Less than 200 Data points for today (175), skipping!
# NXE Exception Less than 200 Data points for today (195), skipping!
# ACA Exception Less than 200 Data points for today (119), skipping!
# AMPH Exception Less than 200 Data points for today (192), skipping!
# GOLF Exception Less than 200 Data points for today (145), skipping!
# DSX Exception Less than 200 Data points for today (150), skipping!
# MRTX Exception Less than 200 Data points for today (199), skipping!
# BV Exception Less than 200 Data points for today (175), skipping!
# 1601 2192 2020-12-03
# CRTO Exception Less than 200 Data points for today (185), skipping!
# OAC Exception Less than 200 Data points for today (191), skipping!
# VAC Exception Less than 200 Data points for today (186), skipping!
# GLOP Exception Less than 200 Data points for today (197), skipping!
# NSCO Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# OSW Exception Less than 200 Data points for today (187), skipping!
# AEHR Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# 1701 2192 2020-12-03
# ...
# LUNA Exception Less than 200 Data points for today (191), skipping!
# 1601 2206 2020-12-10
# MFAC Exception Less than 200 Data points for today (155), skipping!
# CKH Exception Less than 200 Data points for today (189), skipping!
# WYY Exception Less than 200 Data points for today (185), skipping!
# ASGN Exception Less than 200 Data points for today (182), skipping!
# BDC Exception Less than 200 Data points for today (178), skipping!
# TRHC Exception Less than 200 Data points for today (197), skipping!
# ENS Exception Less than 200 Data points for today (190), skipping!
# SIMO Exception Less than 200 Data points for today (169), skipping!
# PGTI Exception Less than 200 Data points for today (160), skipping!
# EME Exception Less than 200 Data points for today (188), skipping!
# 1701 2206 2020-12-10
# OLED Exception Less than 200 Data points for today (185), skipping!
# BNFT Exception Less than 200 Data points for today (181), skipping!
# GSV Exception Less than 200 Data points for today (178), skipping!
# THCA Exception Less than 200 Data points for today (158), skipping!
# QNST Exception Less than 200 Data points for today (199), skipping!
# VCNX Exception Less than 200 Data points for today (126), skipping!
# AVNS Exception Less than 200 Data points for today (122), skipping!
# AIHS Exception Less than 200 Data points for today (151), skipping!
# 1801 2206 2020-12-10
# FAMI Exception Less than 200 Data points for today (159), skipping!
# OEC Exception Less than 200 Data points for today (180), skipping!
# 1901 2206 2020-12-10
# TLYS Exception Less than 200 Data points for today (177), skipping!
# MOTS Exception Less than 200 Data points for today (194), skipping!
# ALEX Exception Less than 200 Data points for today (188), skipping!
# MX Exception Less than 200 Data points for today (197), skipping!
# MUSA Exception Less than 200 Data points for today (183), skipping!
# ATOM Exception Less than 200 Data points for today (197), skipping!
# SILK Exception Less than 200 Data points for today (150), skipping!
# GNPX Exception Less than 200 Data points for today (193), skipping!
# PPT Exception Less than 200 Data points for today (123), skipping!
# OPTN Exception Less than 200 Data points for today (168), skipping!
# LOPE Exception Less than 200 Data points for today (197), skipping!
# TPTX Exception Less than 200 Data points for today (188), skipping!
# TWI Exception Less than 200 Data points for today (193), skipping!
# HUBG Exception Less than 200 Data points for today (165), skipping!
# 2001 2206 2020-12-10
# PFLT Exception Less than 200 Data points for today (182), skipping!
# WHD Exception Less than 200 Data points for today (186), skipping!
# NEA Exception Less than 200 Data points for today (191), skipping!
# ATHM Exception Less than 200 Data points for today (198), skipping!
# 2101 2206 2020-12-10
# CW Exception Less than 200 Data points for today (193), skipping!
# ZUMZ Exception Less than 200 Data points for today (182), skipping!
# PI Exception Less than 200 Data points for today (169), skipping!
# EVV Exception Less than 200 Data points for today (179), skipping!
# CLPS Exception Less than 200 Data points for today (123), skipping!
# CWK Exception Less than 200 Data points for today (187), skipping!
# FTFT Exception Less than 200 Data points for today (176), skipping!
# 2201 2206 2020-12-10
# MEDP Exception Less than 200 Data points for today (196), skipping!
# 1 2206 2020-12-11
# PNNT Exception Less than 200 Data points for today (189), skipping!
# AQMS Exception Less than 200 Data points for today (178), skipping!
# HX Exception Less than 200 Data points for today (117), skipping!
# JELD Exception Less than 200 Data points for today (191), skipping!
# GVP Exception Less than 200 Data points for today (113), skipping!
# 101 2206 2020-12-11
# TBBK Exception Less than 200 Data points for today (193), skipping!
# DUO Exception Less than 200 Data points for today (143), skipping!
# PTAC Exception Less than 200 Data points for today (174), skipping!
# HJLI Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# HYAC Exception Less than 200 Data points for today (117), skipping!
# AXSM Exception Less than 200 Data points for today (194), skipping!
# BXMX Exception Less than 200 Data points for today (163), skipping!
# HLIT Exception Less than 200 Data points for today (193), skipping!
# BHAT Exception Less than 200 Data points for today (158), skipping!
# BALY Exception Less than 200 Data points for today (196), skipping!
# GBIO Exception Less than 200 Data points for today (194), skipping!
# 201 2206 2020-12-11
# MRTN Exception Less than 200 Data points for today (181), skipping!
# WRAP Exception Less than 200 Data points for today (152), skipping!
# EVBG Exception Less than 200 Data points for today (179), skipping!
# FLXN Exception Less than 200 Data points for today (189), skipping!
# GRIL Exception Less than 200 Data points for today (172), skipping!
# AIMC Exception Less than 200 Data points for today (187), skipping!
# CNR Exception Less than 200 Data points for today (197), skipping!
# ORN Exception Less than 200 Data points for today (199), skipping!
# AAIC Exception Less than 200 Data points for today (145), skipping!
# GLOB Exception Less than 200 Data points for today (146), skipping!
# PDSB Exception Less than 200 Data points for today (166), skipping!
# 301 2206 2020-12-11
# DSSI Exception Less than 200 Data points for today (190), skipping!
# JG Exception Less than 200 Data points for today (151), skipping!
# HGEN Exception Less than 200 Data points for today (195), skipping!
# KOPN Exception Less than 200 Data points for today (176), skipping!
# LKCO Exception Less than 200 Data points for today (135), skipping!
# PRTA Exception Less than 200 Data points for today (158), skipping!
# SVRA Exception Less than 200 Data points for today (152), skipping!
# AVID Exception Less than 200 Data points for today (175), skipping!
# EPAY Exception Less than 200 Data points for today (186), skipping!
# 401 2206 2020-12-11
# SMMC Exception Less than 200 Data points for today (157), skipping!
# ILPT Exception Less than 200 Data points for today (163), skipping!
# MMSI Exception Less than 200 Data points for today (191), skipping!
# LMNL Exception Less than 200 Data points for today (179), skipping!
# USX Exception Less than 200 Data points for today (190), skipping!
# OIIM Exception Less than 200 Data points for today (182), skipping!
# 501 2206 2020-12-11
# GATX Exception Less than 200 Data points for today (191), skipping!
# BCOV Exception Less than 200 Data points for today (186), skipping!
# ETY Exception Less than 200 Data points for today (199), skipping!
# CUB Exception Less than 200 Data points for today (190), skipping!
# WTTR Exception Less than 200 Data points for today (177), skipping!
# TTEK Exception Less than 200 Data points for today (175), skipping!
# XNCR Exception Less than 200 Data points for today (191), skipping!
# AUDC Exception Less than 200 Data points for today (183), skipping!
# CAAP Exception Less than 200 Data points for today (149), skipping!
# 601 2206 2020-12-11
# CCS Exception Less than 200 Data points for today (167), skipping!
# CFMS Exception Less than 200 Data points for today (196), skipping!
# POLA Exception Less than 200 Data points for today (180), skipping!
# ZBRA Exception Less than 200 Data points for today (171), skipping!
# BKCC Exception Less than 200 Data points for today (161), skipping!
# VCRA Exception Less than 200 Data points for today (175), skipping!
# OSW Exception Less than 200 Data points for today (181), skipping!
# 701 2206 2020-12-11
# ALRN Exception Less than 200 Data points for today (198), skipping!
# QTRX Exception Less than 200 Data points for today (185), skipping!
# TSLX Exception Less than 200 Data points for today (196), skipping!
# HOOK Exception Less than 200 Data points for today (166), skipping!
# BNTC Exception Less than 200 Data points for today (185), skipping!
# EVOP Exception Less than 200 Data points for today (144), skipping!
# SPH Exception Less than 200 Data points for today (197), skipping!
# WORX Exception Less than 200 Data points for today (137), skipping!
# VREX Exception Less than 200 Data points for today (170), skipping!
# CASA Exception Less than 200 Data points for today (159), skipping!
# EQ Exception Less than 200 Data points for today (174), skipping!
# ACRE Exception Less than 200 Data points for today (150), skipping!
# 801 2206 2020-12-11
# RETO Exception Less than 200 Data points for today (129), skipping!
# ACIU Exception Less than 200 Data points for today (116), skipping!
# GLOP Exception Less than 200 Data points for today (169), skipping!
# AKRO Exception Less than 200 Data points for today (138), skipping!
# NSCO Exception Less than 200 Data points for today (141), skipping!
# DLX Exception Less than 200 Data points for today (185), skipping!
# VAPO Exception Less than 200 Data points for today (191), skipping!
# HAPP Exception Less than 200 Data points for today (196), skipping!
# 901 2206 2020-12-11
# TACO Exception Less than 200 Data points for today (164), skipping!
# ACMR Exception Less than 200 Data points for today (175), skipping!
# TGH Exception Less than 200 Data points for today (172), skipping!
# CMG Exception Less than 200 Data points for today (177), skipping!
# AVAV Exception Less than 200 Data points for today (199), skipping!
# WEI Exception Less than 200 Data points for today (176), skipping!
# ASLN Exception Less than 200 Data points for today (139), skipping!
# KZIA Exception Less than 200 Data points for today (131), skipping!
# DARE Exception Less than 200 Data points for today (199), skipping!
# CSLT Exception Less than 200 Data points for today (180), skipping!
# 1001 2206 2020-12-11
# SRGA Exception Less than 200 Data points for today (190), skipping!
# BDR Exception Less than 200 Data points for today (139), skipping!
# ABM Exception Less than 200 Data points for today (175), skipping!
# FTAI Exception Less than 200 Data points for today (149), skipping!
# OPES Exception Less than 200 Data points for today (159), skipping!
# 1101 2206 2020-12-11
# SCPH Exception Less than 200 Data points for today (133), skipping!
# E Exception Less than 200 Data points for today (193), skipping!
# LFAC Exception Less than 200 Data points for today (143), skipping!
# SD Exception Less than 200 Data points for today (170), skipping!
# HFRO Exception Less than 200 Data points for today (193), skipping!
# ENSG Exception Less than 200 Data points for today (191), skipping!
# IRT Exception Less than 200 Data points for today (199), skipping!
# 1201 2206 2020-12-11
# BCX Exception Less than 200 Data points for today (199), skipping!
# CTRA Exception Less than 200 Data points for today (193), skipping!
# LITB Exception Less than 200 Data points for today (153), skipping!
# NEW Exception Less than 200 Data points for today (181), skipping!
# PTR Exception Less than 200 Data points for today (189), skipping!
# OESX Exception Less than 200 Data points for today (193), skipping!
# NINE Exception Less than 200 Data points for today (185), skipping!
# PATK Exception Less than 200 Data points for today (143), skipping!
# 1301 2206 2020-12-11
# ATRO Exception Less than 200 Data points for today (192), skipping!
# LPL Exception Less than 200 Data points for today (190), skipping!
# WOR Exception Less than 200 Data points for today (195), skipping!
# SRRK Exception Less than 200 Data points for today (198), skipping!
# WSR Exception Less than 200 Data points for today (198), skipping!
# MEOH Exception Less than 200 Data points for today (199), skipping!
# WRE Exception Less than 200 Data points for today (186), skipping!
# 1401 2206 2020-12-11
# TRNO Exception Less than 200 Data points for today (194), skipping!
# MANH Exception Less than 200 Data points for today (183), skipping!
# NAD Exception Less than 200 Data points for today (154), skipping!
# IPGP Exception Less than 200 Data points for today (164), skipping!
# 1501 2206 2020-12-11
# MWK Exception Less than 200 Data points for today (165), skipping!
# PEGA Exception Less than 200 Data points for today (147), skipping!
# MRCY Exception Less than 200 Data points for today (167), skipping!
# SINO Exception Less than 200 Data points for today (180), skipping!
# GDEN Exception Less than 200 Data points for today (178), skipping!
# SCOR Exception Less than 200 Data points for today (176), skipping!
# ENZ Exception Less than 200 Data points for today (129), skipping!
# UTG Exception Less than 200 Data points for today (165), skipping!
# MEI Exception Less than 200 Data points for today (167), skipping!
# 1601 2206 2020-12-11
# MFAC Exception Less than 200 Data points for today (134), skipping!
# APOG Exception Less than 200 Data points for today (199), skipping!
# SIMO Exception Less than 200 Data points for today (183), skipping!
# PGTI Exception Less than 200 Data points for today (193), skipping!
# ALSK Exception Less than 200 Data points for today (164), skipping!
# BRG Exception Less than 200 Data points for today (168), skipping!
# CWST Exception Less than 200 Data points for today (165), skipping!
# 1701 2206 2020-12-11
# EXPO Exception Less than 200 Data points for today (188), skipping!
# OLED Exception Less than 200 Data points for today (175), skipping!
# BNFT Exception Less than 200 Data points for today (171), skipping!
# GSV Exception Less than 200 Data points for today (115), skipping!
# QNST Exception Less than 200 Data points for today (195), skipping!
# FBM Exception Less than 200 Data points for today (194), skipping!
# VRTU Exception Less than 200 Data points for today (163), skipping!
# VCNX Exception Less than 200 Data points for today (169), skipping!
# RTLR Exception Less than 200 Data points for today (174), skipping!
# AVNS Exception Less than 200 Data points for today (180), skipping!
# AIHS Exception Less than 200 Data points for today (136), skipping!
# 1801 2206 2020-12-11
# SAIA Exception Less than 200 Data points for today (185), skipping!
# SXTC Exception Less than 200 Data points for today (190), skipping!
# DRRX Exception Less than 200 Data points for today (182), skipping!
# BMCH Exception Less than 200 Data points for today (183), skipping!
# OEC Exception Less than 200 Data points for today (171), skipping!
# 1901 2206 2020-12-11
# GSKY Exception Less than 200 Data points for today (195), skipping!
# TLYS Exception Less than 200 Data points for today (193), skipping!
# MUSA Exception Less than 200 Data points for today (196), skipping!
# FLMN Exception Less than 200 Data points for today (187), skipping!
# CTT Exception Less than 200 Data points for today (154), skipping!
# GCO Exception Less than 200 Data points for today (185), skipping!
# PRLB Exception Less than 200 Data points for today (193), skipping!
# HUBG Exception Less than 200 Data points for today (196), skipping!
# 2001 2206 2020-12-11
# TNAV Exception Less than 200 Data points for today (164), skipping!
# LEJU Exception Less than 200 Data points for today (146), skipping!
# MTLS Exception Less than 200 Data points for today (190), skipping!
# BCEI Exception Less than 200 Data points for today (189), skipping!
# BV Exception Less than 200 Data points for today (135), skipping!
# NEA Exception Less than 200 Data points for today (171), skipping!
# TCPC Exception Less than 200 Data points for today (170), skipping!
# XAN Exception Less than 200 Data points for today (193), skipping!
# DIOD Exception Less than 200 Data points for today (166), skipping!
# 2101 2206 2020-12-11
# APRE Exception Less than 200 Data points for today (182), skipping!
# RVT Exception Less than 200 Data points for today (162), skipping!
# ZUMZ Exception Less than 200 Data points for today (173), skipping!
# HAE Exception Less than 200 Data points for today (191), skipping!
# PI Exception Less than 200 Data points for today (166), skipping!
# EVV Exception Less than 200 Data points for today (187), skipping!
# CLPS Exception Less than 200 Data points for today (143), skipping!
# LEGN Exception Less than 200 Data points for today (196), skipping!
# CWK Exception Less than 200 Data points for today (186), skipping!
# FTFT Exception Less than 200 Data points for today (113), skipping!
# 2201 2206 2020-12-11
# MEDP Exception Less than 200 Data points for today (177), skipping!
# Errors: 1695 21990 0.077

# %%
# df_train - Create dataframe
if ls_df_t:
    df_t = pd.concat(ls_df_t)

# df_train - cleanup columns and NAs
ls_col = [
    'is_profit',
    'rsi14',
    'sma9_var',
    'sma180_var',
    'vwap_var',
    'spread14_e',
    'volume14_34_var',
    'prev_close_var',
    'prev_floor_var',
    'prev_ceil_var',
    'prev1_candle_score',
    'prev2_candle_score',
    'prev3_candle_score',
    'mins_from_start',
    'valley_interval_mins',
    'valley_close_score',
    'valley_rsi_score',
    'day_open_var',
    'open_from_prev_close_var',
    'ceil_var',
    'floor_var',
    ###
    'sym',
    'datetime',
    'profit',
    'prev_close',
    'divergence',
]
df_t = df_t[ls_col]
df_t = df_t.dropna()
#cat_cols = df_t.select_dtypes(include=object).columns
#df_t[cat_cols] = df_t[cat_cols].fillna('none').astype('category')
print(df_t.info())

# df_train - Export
timestamp = datetime.datetime.now().strftime('%Y%m%d_%H%M')
f = f'{dir_train}df_train_{timestamp}.parquet'
df_t.to_parquet(f)
print(f, 'saved!')
beeps()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63644 entries, 284 to 279
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   is_profit                 63644 non-null  bool
#  1   rsi14                     63644 non-null  float64
#  2   sma9_var                  63644 non-null  float64
#  3   sma180_var                63644 non-null  float64
#  4   vwap_var                  63644 non-null  float64
#  5   spread14_e                63644 non-null  float64
#  6   volume14_34_var           63644 non-null  float64
#  7   prev_close_var            63644 non-null  float64
#  8   prev_floor_var            63644 non-null  float64
#  9   prev_ceil_var             63644 non-null  float64
#  10  prev1_candle_score        63644 non-null  float64
#  11  prev2_candle_score        63644 non-null  float64
#  12  prev3_candle_score        63644 non-null  float64
#  13  mins_from_start           63644 non-null  float64
#  14  valley_interval_mins      63644 non-null  float64
#  15  valley_close_score        63644 non-null  float64
#  16  valley_rsi_score          63644 non-null  float64
#  17  day_open_var              63644 non-null  float64
#  18  open_from_prev_close_var  63644 non-null  float64
#  19  ceil_var                  63644 non-null  float64
#  20  floor_var                 63644 non-null  float64
#  21  sym                       63644 non-null  object
#  22  datetime                  63644 non-null  datetime64[ns]
#  23  profit                    63644 non-null  float64
#  24  prev_close                63644 non-null  float64
#  25  divergence                63644 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(22), object(2)
# memory usage: 12.7+ MB
# None
# D:/Michael/github_projects/five_minute_midas/data/train/df_train_20201212_1545.parquet saved!

# %% [markdown]
# # Debug

# %%
date_str = '2020-12-03'
live_data = 1
df_c = get_df_c('BYND', date_str, live_data, db, target_profit, target_loss)
df_c
# Out:
#                datetime       close        sma9      sma180      rsi14  \
# 0   2020-12-03 09:30:00  140.699997  138.554767  137.843928  86.772514
# 1   2020-12-03 09:31:00  141.644196  138.950789  137.864007  89.744043
# 2   2020-12-03 09:32:00  140.960007  139.288567  137.879007  76.357938
# 3   2020-12-03 09:33:00  140.750000  139.576345  137.892674  72.770016
# 4   2020-12-03 09:34:00  140.850006  139.865234  137.907229  73.410743
# ..                  ...         ...         ...         ...        ...
# 104 2020-12-03 11:14:00  141.524994  141.528544  140.172950  45.999271
# 105 2020-12-03 11:15:00  141.486893  141.481532  140.193323  45.047214
# 106 2020-12-03 11:16:00  141.529999  141.437088  140.216323  46.398883
# 107 2020-12-03 11:17:00  141.800003  141.455977  140.240378  54.026739
# 108 2020-12-03 11:18:13  141.679398  141.473687  140.263208  50.565258
#
#            vwap  sma9_var  sma180_var  vwap_var  spread14_e  ...  \
# 0    140.356664  0.015483    0.020720  0.002446    0.000761  ...
# 1    140.509232  0.019384    0.027420  0.008078    0.001602  ...
# 2    140.535142  0.012000    0.022346  0.003023    0.001653  ...
# 3    140.560061  0.008409    0.020721  0.001351    0.001461  ...
# 4    140.567085  0.007041    0.021339  0.002013    0.001361  ...
# ..          ...       ...         ...       ...         ...  ...
# 104  141.756592 -0.000025    0.009646 -0.001634    0.000655  ...
# 105  141.756167  0.000038    0.009227 -0.001900    0.000650  ...
# 106  141.755768  0.000657    0.009369 -0.001593    0.000610  ...
# 107  141.755513  0.002432    0.011121  0.000314    0.000741  ...
# 108  141.755513  0.001454    0.010097 -0.000537    0.000642  ...
#
#      day_open_var  open_from_prev_close_var        ceil  ceil_var       floor  \
# 0        0.000000                  0.015371  140.699997  0.000000  140.699997
# 1        0.006711                  0.015371  141.644196  0.000000  140.699997
# 2        0.001848                  0.015371  141.644196 -0.004830  140.699997
# 3        0.000355                  0.015371  141.644196 -0.006313  140.699997
# 4        0.001066                  0.015371  141.644196 -0.005607  140.699997
# ..            ...                       ...         ...       ...         ...
# 104      0.005864                  0.015371  143.250000 -0.012042  140.369995
# 105      0.005593                  0.015371  143.250000 -0.012308  140.369995
# 106      0.005899                  0.015371  143.250000 -0.012007  140.369995
# 107      0.007818                  0.015371  143.250000 -0.010122  140.369995
# 108      0.006961                  0.015371  143.250000 -0.010964  140.369995
#
#      floor_var   sym  actual_buy_price  profit  is_profit
# 0     0.000000  BYND        140.960007    None      False
# 1     0.006711  BYND        140.750000    None      False
# 2     0.001848  BYND        140.850006    None      False
# 3     0.000355  BYND        140.369995    None      False
# 4     0.001066  BYND        140.492905    None      False
# ..         ...   ...               ...     ...        ...
# 104   0.008228  BYND        141.529999    None      False
# 105   0.007957  BYND        141.800003    None      False
# 106   0.008264  BYND        141.679398    None      False
# 107   0.010187  BYND               NaN    None      False
# 108   0.009328  BYND               NaN    None      False
#
# [109 rows x 36 columns]
