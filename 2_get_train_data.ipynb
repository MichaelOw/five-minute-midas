# %%
import os
import json
import pickle
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import yfinance as yf
from src.db import DataBase
import matplotlib.pyplot as plt
from src.utils_general import beeps
from src.utils_stocks import get_df_c
from src.utils_general import get_df_sym
from src.utils_general import plot_divergences
from src.utils_date import get_ls_date_str_from_db
dir_db = os.path.join(os.getcwd(), 'data', 'db')
dir_train = os.path.join(os.getcwd(), 'data', 'train')
db = DataBase([], dir_db=dir_db)

live_data = 0
target_profit = 0.011
target_loss = -0.031
ls_date_str = get_ls_date_str_from_db('2020-12-14', '2022-01-01', db) #'2020-06-23'
print(ls_date_str[0], ls_date_str[-1])
# Out:
# 2020-12-14 2020-12-18

# %%
count, count_e = 0, 0
ls_df_t = []
for date_str in ls_date_str:
    df_sym = get_df_sym(db, date_str)
    for i, tup in df_sym.iterrows():
        count+=1
        if i%100==0: print(i+1, df_sym.shape[0], date_str)
        try:
            df_c = get_df_c(tup['sym'], date_str, live_data, db, target_profit, target_loss)
            ls_df_t.append(df_c[df_c['divergence']!=''])
        except Exception as e:
            print(tup['sym'], type(e).__name__, e)
            count_e+=1
print('Errors:', count_e, count, round(count_e/count, 3))
# Out:
# 1 2305 2020-12-14
# VIE Exception No intraday(minute interval) data for previous day!
# TUFN Exception No intraday(minute interval) data for previous day!
# SPRO Exception No intraday(minute interval) data for previous day!
# AQMS Exception Less than 200 Data points for today (163), skipping!
# CODI Exception No intraday(minute interval) data for previous day!
# OAS Exception No intraday(minute interval) data for previous day!
# HTBK Exception No intraday(minute interval) data for previous day!
# 101 2305 2020-12-14
# CURO Exception No intraday(minute interval) data for previous day!
# MODN Exception Less than 200 Data points for today (164), skipping!
# TBBK Exception Less than 200 Data points for today (135), skipping!
# TDY Exception No intraday(minute interval) data for previous day!
# WOW Exception No intraday(minute interval) data for previous day!
# TMBR Exception No intraday(minute interval) data for previous day!
# JOE Exception No intraday(minute interval) data for previous day!
# TCMD Exception No intraday(minute interval) data for previous day!
# EPC Exception Less than 200 Data points for today (178), skipping!
# ALVR Exception No intraday(minute interval) data for previous day!
# SCHL Exception No intraday(minute interval) data for previous day!
# ERII Exception No intraday(minute interval) data for previous day!
# BIO Exception No intraday(minute interval) data for previous day!
# SXT Exception No intraday(minute interval) data for previous day!
# BHAT Exception Less than 200 Data points for today (192), skipping!
# HSTO Exception No intraday(minute interval) data for previous day!
# VBTX Exception No intraday(minute interval) data for previous day!
# NXGN Exception No intraday(minute interval) data for previous day!
# 201 2305 2020-12-14
# AOD Exception No intraday(minute interval) data for previous day!
# PQG Exception No intraday(minute interval) data for previous day!
# HYMC Exception No intraday(minute interval) data for previous day!
# HYT Exception Less than 200 Data points for today (151), skipping!
# PLYM Exception No intraday(minute interval) data for previous day!
# VERX Exception No intraday(minute interval) data for previous day!
# NVR Exception No intraday(minute interval) data for previous day!
# EOLS Exception No intraday(minute interval) data for previous day!
# AWH Exception Less than 200 Data points for today (178), skipping!
# 301 2305 2020-12-14
# MIRM Exception No intraday(minute interval) data for previous day!
# KRA Exception No intraday(minute interval) data for previous day!
# DSSI Exception Less than 200 Data points for today (164), skipping!
# ANPC Exception No intraday(minute interval) data for previous day!
# TFSL Exception No intraday(minute interval) data for previous day!
# WSFS Exception No intraday(minute interval) data for previous day!
# CNSP Exception No intraday(minute interval) data for previous day!
# KOPN Exception Less than 200 Data points for today (188), skipping!
# TISI Exception No intraday(minute interval) data for previous day!
# IBP Exception No intraday(minute interval) data for previous day!
# SBBP Exception No intraday(minute interval) data for previous day!
# 401 2305 2020-12-14
# SLP Exception No intraday(minute interval) data for previous day!
# JPC Exception Less than 200 Data points for today (180), skipping!
# BCSF Exception No intraday(minute interval) data for previous day!
# MCY Exception No intraday(minute interval) data for previous day!
# ANCN Exception No intraday(minute interval) data for previous day!
# GLRE Exception Less than 200 Data points for today (163), skipping!
# AEIS Exception Less than 200 Data points for today (197), skipping!
# PAR Exception No intraday(minute interval) data for previous day!
# HVT Exception No intraday(minute interval) data for previous day!
# REED Exception Less than 200 Data points for today (175), skipping!
# 501 2305 2020-12-14
# MNRO Exception No intraday(minute interval) data for previous day!
# SWM Exception No intraday(minute interval) data for previous day!
# GTYH Exception No intraday(minute interval) data for previous day!
# GDV Exception No intraday(minute interval) data for previous day!
# NDRA Exception No intraday(minute interval) data for previous day!
# CAMP Exception No intraday(minute interval) data for previous day!
# MREO Exception Less than 200 Data points for today (197), skipping!
# CUB Exception Less than 200 Data points for today (194), skipping!
# WTS Exception No intraday(minute interval) data for previous day!
# DAKT Exception No intraday(minute interval) data for previous day!
# FINV Exception No intraday(minute interval) data for previous day!
# 601 2305 2020-12-14
# ALRM Exception Less than 200 Data points for today (174), skipping!
# TAST Exception Less than 200 Data points for today (195), skipping!
# MHO Exception No intraday(minute interval) data for previous day!
# CWBR Exception No intraday(minute interval) data for previous day!
# SIGA Exception No intraday(minute interval) data for previous day!
# LDL Exception No intraday(minute interval) data for previous day!
# CFMS Exception Less than 200 Data points for today (198), skipping!
# ETH Exception No intraday(minute interval) data for previous day!
# BAK Exception No intraday(minute interval) data for previous day!
# SMMT Exception No intraday(minute interval) data for previous day!
# 701 2305 2020-12-14
# MLI Exception No intraday(minute interval) data for previous day!
# VCRA Exception Less than 200 Data points for today (191), skipping!
# FFIC Exception No intraday(minute interval) data for previous day!
# TFX Exception No intraday(minute interval) data for previous day!
# PBFX Exception No intraday(minute interval) data for previous day!
# GSBD Exception No intraday(minute interval) data for previous day!
# ALTR Exception No intraday(minute interval) data for previous day!
# ITRI Exception No intraday(minute interval) data for previous day!
# CBZ Exception No intraday(minute interval) data for previous day!
# MDGL Exception No intraday(minute interval) data for previous day!
# 801 2305 2020-12-14
# MRAM Exception No intraday(minute interval) data for previous day!
# GOOD Exception No intraday(minute interval) data for previous day!
# SMP Exception No intraday(minute interval) data for previous day!
# LIND Exception Less than 200 Data points for today (170), skipping!
# GNLN Exception Less than 200 Data points for today (134), skipping!
# METX Exception No intraday(minute interval) data for previous day!
# IMMR Exception No intraday(minute interval) data for previous day!
# OSPN Exception No intraday(minute interval) data for previous day!
# PRVL Exception No intraday(minute interval) data for previous day!
# UMH Exception No intraday(minute interval) data for previous day!
# CSII Exception No intraday(minute interval) data for previous day!
# FREQ Exception No intraday(minute interval) data for previous day!
# CGBD Exception No intraday(minute interval) data for previous day!
# GLPG Exception No intraday(minute interval) data for previous day!
# 901 2305 2020-12-14
# NVRO Exception No intraday(minute interval) data for previous day!
# TR Exception Less than 200 Data points for today (183), skipping!
# STOK Exception No intraday(minute interval) data for previous day!
# AKRO Exception Less than 200 Data points for today (163), skipping!
# PHAT Exception No intraday(minute interval) data for previous day!
# ACTG Exception No intraday(minute interval) data for previous day!
# XENT Exception No intraday(minute interval) data for previous day!
# B Exception No intraday(minute interval) data for previous day!
# HAPP Exception Less than 200 Data points for today (163), skipping!
# MSGE Exception No intraday(minute interval) data for previous day!
# TNET Exception Less than 200 Data points for today (185), skipping!
# WEI Exception Less than 200 Data points for today (180), skipping!
# OSMT Exception No intraday(minute interval) data for previous day!
# FUL Exception Less than 200 Data points for today (197), skipping!
# 1001 2305 2020-12-14
# RCEL Exception No intraday(minute interval) data for previous day!
# SAFM Exception No intraday(minute interval) data for previous day!
# THBR Exception No intraday(minute interval) data for previous day!
# CSLT Exception Less than 200 Data points for today (135), skipping!
# PRGS Exception No intraday(minute interval) data for previous day!
# NXTC Exception No intraday(minute interval) data for previous day!
# OXSQ Exception No intraday(minute interval) data for previous day!
# TRST Exception No intraday(minute interval) data for previous day!
# MLND Exception No intraday(minute interval) data for previous day!
# BDR Exception Less than 200 Data points for today (153), skipping!
# AMBC Exception No intraday(minute interval) data for previous day!
# AAT Exception No intraday(minute interval) data for previous day!
# 1101 2305 2020-12-14
# RNA Exception No intraday(minute interval) data for previous day!
# CLH Exception No intraday(minute interval) data for previous day!
# EXPC Exception No intraday(minute interval) data for previous day!
# SYBX Exception No intraday(minute interval) data for previous day!
# CTK Exception No intraday(minute interval) data for previous day!
# PLIN Exception No intraday(minute interval) data for previous day!
# XCUR Exception No intraday(minute interval) data for previous day!
# ENV Exception Less than 200 Data points for today (151), skipping!
# FSS Exception No intraday(minute interval) data for previous day!
# CIO Exception No intraday(minute interval) data for previous day!
# QUAD Exception No intraday(minute interval) data for previous day!
# AUB Exception No intraday(minute interval) data for previous day!
# 1201 2305 2020-12-14
# PFS Exception No intraday(minute interval) data for previous day!
# CHH Exception No intraday(minute interval) data for previous day!
# HFRO Exception Less than 200 Data points for today (198), skipping!
# TAC Exception No intraday(minute interval) data for previous day!
# CLDT Exception No intraday(minute interval) data for previous day!
# IIIV Exception No intraday(minute interval) data for previous day!
# TGP Exception No intraday(minute interval) data for previous day!
# 1301 2305 2020-12-14
# GOLF Exception No intraday(minute interval) data for previous day!
# CHY Exception No intraday(minute interval) data for previous day!
# ATRO Exception Less than 200 Data points for today (188), skipping!
# KIN Exception No intraday(minute interval) data for previous day!
# LPL Exception Less than 200 Data points for today (185), skipping!
# GRTS Exception No intraday(minute interval) data for previous day!
# SCYX Exception No intraday(minute interval) data for previous day!
# 1401 2305 2020-12-14
# UFPI Exception No intraday(minute interval) data for previous day!
# AHH Exception No intraday(minute interval) data for previous day!
# TLK Exception Less than 200 Data points for today (199), skipping!
# ASC Exception No intraday(minute interval) data for previous day!
# AIZ Exception Less than 200 Data points for today (175), skipping!
# APEN Exception No intraday(minute interval) data for previous day!
# ACRS Exception No intraday(minute interval) data for previous day!
# MGTX Exception No intraday(minute interval) data for previous day!
# NUS Exception Less than 200 Data points for today (196), skipping!
# LFC Exception Less than 200 Data points for today (194), skipping!
# 1501 2305 2020-12-14
# MANH Exception Less than 200 Data points for today (162), skipping!
# ACA Exception No intraday(minute interval) data for previous day!
# LEU Exception No intraday(minute interval) data for previous day!
# NAD Exception Less than 200 Data points for today (198), skipping!
# CSGP Exception No intraday(minute interval) data for previous day!
# IPGP Exception Less than 200 Data points for today (172), skipping!
# EVLO Exception No intraday(minute interval) data for previous day!
# BDTX Exception No intraday(minute interval) data for previous day!
# HTLD Exception No intraday(minute interval) data for previous day!
# YMAB Exception No intraday(minute interval) data for previous day!
# LOCO Exception No intraday(minute interval) data for previous day!
# LOGC Exception No intraday(minute interval) data for previous day!
# NPA Exception No intraday(minute interval) data for previous day!
# AWR Exception No intraday(minute interval) data for previous day!
# 1601 2305 2020-12-14
# NRK Exception No intraday(minute interval) data for previous day!
# NBSE Exception No intraday(minute interval) data for previous day!
# CCM Exception No intraday(minute interval) data for previous day!
# ENVA Exception No intraday(minute interval) data for previous day!
# CDTX Exception Less than 200 Data points for today (198), skipping!
# DMTK Exception No intraday(minute interval) data for previous day!
# FENG Exception No intraday(minute interval) data for previous day!
# CASI Exception No intraday(minute interval) data for previous day!
# 1701 2305 2020-12-14
# ENS Exception Less than 200 Data points for today (191), skipping!
# PRAA Exception No intraday(minute interval) data for previous day!
# PRAH Exception No intraday(minute interval) data for previous day!
# DTEA Exception No intraday(minute interval) data for previous day!
# CLEU Exception No intraday(minute interval) data for previous day!
# EXPO Exception Less than 200 Data points for today (198), skipping!
# AZRE Exception No intraday(minute interval) data for previous day!
# FRG Exception No intraday(minute interval) data for previous day!
# MTRX Exception No intraday(minute interval) data for previous day!
# TEO Exception No intraday(minute interval) data for previous day!
# 1801 2305 2020-12-14
# SAH Exception No intraday(minute interval) data for previous day!
# QNST Exception Less than 200 Data points for today (187), skipping!
# PETQ Exception No intraday(minute interval) data for previous day!
# HONE Exception No intraday(minute interval) data for previous day!
# IGR Exception Less than 200 Data points for today (187), skipping!
# NFBK Exception No intraday(minute interval) data for previous day!
# ARQT Exception No intraday(minute interval) data for previous day!
# AIHS Exception Less than 200 Data points for today (157), skipping!
# GRNQ Exception No intraday(minute interval) data for previous day!
# 1901 2305 2020-12-14
# FIX Exception No intraday(minute interval) data for previous day!
# PIRS Exception No intraday(minute interval) data for previous day!
# SXTC Exception Less than 200 Data points for today (184), skipping!
# HARP Exception No intraday(minute interval) data for previous day!
# OGS Exception No intraday(minute interval) data for previous day!
# BHLB Exception No intraday(minute interval) data for previous day!
# LE Exception Less than 200 Data points for today (199), skipping!
# USCR Exception No intraday(minute interval) data for previous day!
# FN Exception No intraday(minute interval) data for previous day!
# LCI Exception No intraday(minute interval) data for previous day!
# REVG Exception No intraday(minute interval) data for previous day!
# TLYS Exception Less than 200 Data points for today (181), skipping!
# ALBO Exception No intraday(minute interval) data for previous day!
# 2001 2305 2020-12-14
# SWTX Exception No intraday(minute interval) data for previous day!
# LAND Exception No intraday(minute interval) data for previous day!
# CSGS Exception No intraday(minute interval) data for previous day!
# STC Exception No intraday(minute interval) data for previous day!
# OCX Exception No intraday(minute interval) data for previous day!
# SILK Exception Less than 200 Data points for today (182), skipping!
# GNPX Exception Less than 200 Data points for today (165), skipping!
# PUBM Exception No intraday(minute interval) data for previous day!
# PRLB Exception Less than 200 Data points for today (193), skipping!
# FOE Exception No intraday(minute interval) data for previous day!
# ALLK Exception No intraday(minute interval) data for previous day!
# VVOS Exception No intraday(minute interval) data for previous day!
# UBA Exception No intraday(minute interval) data for previous day!
# TDW Exception No intraday(minute interval) data for previous day!
# 2101 2305 2020-12-14
# SMCI Exception No intraday(minute interval) data for previous day!
# CERT Exception No intraday(minute interval) data for previous day!
# BSM Exception No intraday(minute interval) data for previous day!
# KOP Exception No intraday(minute interval) data for previous day!
# SPXC Exception No intraday(minute interval) data for previous day!
# NEA Exception Less than 200 Data points for today (158), skipping!
# IMAB Exception Less than 200 Data points for today (153), skipping!
# AGLE Exception No intraday(minute interval) data for previous day!
# DASH Exception No intraday(minute interval) data for previous day!
# BRC Exception No intraday(minute interval) data for previous day!
# ASPN Exception No intraday(minute interval) data for previous day!
# NVG Exception No intraday(minute interval) data for previous day!
# NMCO Exception No intraday(minute interval) data for previous day!
# BSTZ Exception No intraday(minute interval) data for previous day!
# MIND Exception No intraday(minute interval) data for previous day!
# 2201 2305 2020-12-14
# INGN Exception No intraday(minute interval) data for previous day!
# BHE Exception No intraday(minute interval) data for previous day!
# RVT Exception Less than 200 Data points for today (183), skipping!
# ABNB Exception No intraday(minute interval) data for previous day!
# HZON Exception No intraday(minute interval) data for previous day!
# RDHL Exception No intraday(minute interval) data for previous day!
# EVV Exception Less than 200 Data points for today (159), skipping!
# FTFT Exception Less than 200 Data points for today (122), skipping!
# CWT Exception No intraday(minute interval) data for previous day!
# MEDP Exception Less than 200 Data points for today (189), skipping!
# CHDN Exception No intraday(minute interval) data for previous day!
# 2301 2305 2020-12-14
# CYTH Exception No intraday(minute interval) data for previous day!
# FDMT Exception No intraday(minute interval) data for previous day!
# BTWNW Exception No intraday(minute interval) data for previous day!
# HYFM Exception No intraday(minute interval) data for previous day!
# 1 2305 2020-12-15
# SPRO Exception Less than 200 Data points for today (194), skipping!
# AQMS Exception Less than 200 Data points for today (154), skipping!
# OAS Exception Less than 200 Data points for today (165), skipping!
# HTBK Exception Less than 200 Data points for today (194), skipping!
# ADCT Exception Less than 200 Data points for today (193), skipping!
# 101 2305 2020-12-15
# CURO Exception Less than 200 Data points for today (149), skipping!
# WOW Exception Less than 200 Data points for today (174), skipping!
# SCHL Exception Less than 200 Data points for today (137), skipping!
# BLI Exception Less than 200 Data points for today (179), skipping!
# SXT Exception Less than 200 Data points for today (178), skipping!
# NXGN Exception Less than 200 Data points for today (182), skipping!
# 201 2305 2020-12-15
# VERX Exception Less than 200 Data points for today (144), skipping!
# WRAP Exception Less than 200 Data points for today (184), skipping!
# NVR Exception Less than 200 Data points for today (170), skipping!
# AIMC Exception Less than 200 Data points for today (173), skipping!
# RAIL Exception Less than 200 Data points for today (194), skipping!
# 301 2305 2020-12-15
# ANIX Exception Less than 200 Data points for today (198), skipping!
# DSSI Exception Less than 200 Data points for today (194), skipping!
# BLKB Exception Less than 200 Data points for today (191), skipping!
# CNSP Exception Less than 200 Data points for today (101), skipping!
# KOPN Exception Less than 200 Data points for today (178), skipping!
# KT Exception Less than 200 Data points for today (192), skipping!
# TISI Exception Less than 200 Data points for today (142), skipping!
# 401 2305 2020-12-15
# SLP Exception Less than 200 Data points for today (159), skipping!
# BNED Exception Less than 200 Data points for today (178), skipping!
# CLS Exception Less than 200 Data points for today (172), skipping!
# EPAY Exception Less than 200 Data points for today (192), skipping!
# ATRC Exception Less than 200 Data points for today (179), skipping!
# HVT Exception Less than 200 Data points for today (175), skipping!
# REED Exception Less than 200 Data points for today (159), skipping!
# 501 2305 2020-12-15
# GTYH Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# NDRA Exception Less than 200 Data points for today (195), skipping!
# CUB Exception Less than 200 Data points for today (166), skipping!
# WTS Exception Less than 200 Data points for today (182), skipping!
# 601 2305 2020-12-15
# AXS Exception Less than 200 Data points for today (199), skipping!
# FEI Exception Less than 200 Data points for today (172), skipping!
# PTI Exception Less than 200 Data points for today (188), skipping!
# BAK Exception Less than 200 Data points for today (138), skipping!
# 701 2305 2020-12-15
# OSW Exception Less than 200 Data points for today (188), skipping!
# CRNT Exception Less than 200 Data points for today (191), skipping!
# GSBD Exception Less than 200 Data points for today (176), skipping!
# ALTR Exception Less than 200 Data points for today (168), skipping!
# JNCE Exception Less than 200 Data points for today (180), skipping!
# MDGL Exception Less than 200 Data points for today (145), skipping!
# 801 2305 2020-12-15
# MRAM Exception Less than 200 Data points for today (130), skipping!
# SPH Exception Less than 200 Data points for today (186), skipping!
# GOOD Exception Less than 200 Data points for today (195), skipping!
# SMP Exception Less than 200 Data points for today (166), skipping!
# HOLI Exception Less than 200 Data points for today (164), skipping!
# PRQR Exception Less than 200 Data points for today (117), skipping!
# GNLN Exception Less than 200 Data points for today (176), skipping!
# GTT Exception Less than 200 Data points for today (197), skipping!
# ACIU Exception Less than 200 Data points for today (170), skipping!
# IMMR Exception Less than 200 Data points for today (187), skipping!
# OSPN Exception Less than 200 Data points for today (166), skipping!
# RAPT Exception Less than 200 Data points for today (170), skipping!
# CSII Exception Less than 200 Data points for today (183), skipping!
# CGBD Exception Less than 200 Data points for today (191), skipping!
# GLPG Exception Less than 200 Data points for today (150), skipping!
# 901 2305 2020-12-15
# TR Exception Less than 200 Data points for today (179), skipping!
# STOK Exception Less than 200 Data points for today (199), skipping!
# AKRO Exception Less than 200 Data points for today (109), skipping!
# PTCT Exception Less than 200 Data points for today (195), skipping!
# PHAT Exception Less than 200 Data points for today (155), skipping!
# HAPP Exception Less than 200 Data points for today (177), skipping!
# SFNC Exception Less than 200 Data points for today (198), skipping!
# OSMT Exception Less than 200 Data points for today (193), skipping!
# 1001 2305 2020-12-15
# THBR Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# PRTK Exception Less than 200 Data points for today (188), skipping!
# MLND Exception Less than 200 Data points for today (138), skipping!
# AMBC Exception Less than 200 Data points for today (160), skipping!
# AAT Exception Less than 200 Data points for today (196), skipping!
# 1101 2305 2020-12-15
# RNA Exception Less than 200 Data points for today (109), skipping!
# EXPC Exception Null found in df_i columns: ['sma180', 'rsi14', 'sma180_var'], skipping!
# PLIN Exception Less than 200 Data points for today (114), skipping!
# ZYME Exception Less than 200 Data points for today (193), skipping!
# XCUR Exception Less than 200 Data points for today (161), skipping!
# FTDR Exception Less than 200 Data points for today (182), skipping!
# AUB Exception Less than 200 Data points for today (164), skipping!
# SUP Exception Less than 200 Data points for today (187), skipping!
# 1201 2305 2020-12-15
# HFRO Exception Less than 200 Data points for today (189), skipping!
# IIIV Exception Less than 200 Data points for today (193), skipping!
# ENTX Exception Less than 200 Data points for today (170), skipping!
# TGP Exception Less than 200 Data points for today (179), skipping!
# 1301 2305 2020-12-15
# NEW Exception Less than 200 Data points for today (192), skipping!
# CHY Exception Less than 200 Data points for today (142), skipping!
# ATRO Exception Less than 200 Data points for today (197), skipping!
# KIN Exception Less than 200 Data points for today (191), skipping!
# GRTS Exception Less than 200 Data points for today (196), skipping!
# SCYX Exception Less than 200 Data points for today (103), skipping!
# 1401 2305 2020-12-15
# CRY Exception Less than 200 Data points for today (169), skipping!
# CTB Exception Less than 200 Data points for today (198), skipping!
# APEN Exception Less than 200 Data points for today (68), skipping!
# ACRS Exception Less than 200 Data points for today (182), skipping!
# MGTX Exception Less than 200 Data points for today (176), skipping!
# NUS Exception Less than 200 Data points for today (187), skipping!
# LFC Exception Less than 200 Data points for today (179), skipping!
# 1501 2305 2020-12-15
# LEU Exception Less than 200 Data points for today (189), skipping!
# ICLK Exception Less than 200 Data points for today (180), skipping!
# CSGP Exception Less than 200 Data points for today (191), skipping!
# MWK Exception Less than 200 Data points for today (199), skipping!
# YMAB Exception Less than 200 Data points for today (194), skipping!
# NPA Exception Less than 200 Data points for today (59), skipping!
# AWR Exception Less than 200 Data points for today (199), skipping!
# 1601 2305 2020-12-15
# NRK Exception Less than 200 Data points for today (133), skipping!
# NBSE Exception Less than 200 Data points for today (199), skipping!
# CCM Exception Less than 200 Data points for today (86), skipping!
# CDTX Exception Less than 200 Data points for today (160), skipping!
# CASI Exception Less than 200 Data points for today (158), skipping!
# WYY Exception Less than 200 Data points for today (175), skipping!
# 1701 2305 2020-12-15
# BRY Exception Less than 200 Data points for today (194), skipping!
# DTEA Exception Less than 200 Data points for today (169), skipping!
# CLEU Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# BRG Exception Less than 200 Data points for today (188), skipping!
# SND Exception Less than 200 Data points for today (173), skipping!
# TEO Exception Less than 200 Data points for today (182), skipping!
# HPR Exception Less than 200 Data points for today (184), skipping!
# 1801 2305 2020-12-15
# QNST Exception Less than 200 Data points for today (198), skipping!
# AIHS Exception Less than 200 Data points for today (162), skipping!
# GRNQ Exception Less than 200 Data points for today (58), skipping!
# 1901 2305 2020-12-15
# SXTC Exception Less than 200 Data points for today (181), skipping!
# OGS Exception Less than 200 Data points for today (160), skipping!
# UTF Exception Less than 200 Data points for today (196), skipping!
# USCR Exception Less than 200 Data points for today (195), skipping!
# CNA Exception Less than 200 Data points for today (187), skipping!
# LCI Exception Less than 200 Data points for today (151), skipping!
# 2001 2305 2020-12-15
# MX Exception Less than 200 Data points for today (172), skipping!
# LAND Exception Less than 200 Data points for today (195), skipping!
# DFIN Exception Less than 200 Data points for today (190), skipping!
# GNPX Exception Less than 200 Data points for today (171), skipping!
# GCO Exception Less than 200 Data points for today (174), skipping!
# ALLK Exception Less than 200 Data points for today (191), skipping!
# VVOS Exception Less than 200 Data points for today (174), skipping!
# SNP Exception Less than 200 Data points for today (181), skipping!
# UBA Exception Less than 200 Data points for today (160), skipping!
# 2101 2305 2020-12-15
# KOP Exception Less than 200 Data points for today (159), skipping!
# BV Exception Less than 200 Data points for today (180), skipping!
# NEA Exception Less than 200 Data points for today (184), skipping!
# IMAB Exception Less than 200 Data points for today (135), skipping!
# NMCO Exception Less than 200 Data points for today (143), skipping!
# MIND Exception Less than 200 Data points for today (192), skipping!
# 2201 2305 2020-12-15
# GGAL Exception Less than 200 Data points for today (192), skipping!
# AIKI Exception Less than 200 Data points for today (199), skipping!
# EPAM Exception Less than 200 Data points for today (181), skipping!
# FTFT Exception Less than 200 Data points for today (192), skipping!
# 2301 2305 2020-12-15
# CYTH Exception Less than 200 Data points for today (100), skipping!
# 1 2305 2020-12-16
# VIE Exception Less than 200 Data points for today (164), skipping!
# TUFN Exception Less than 200 Data points for today (193), skipping!
# TFFP Exception Less than 200 Data points for today (195), skipping!
# UPLD Exception Less than 200 Data points for today (186), skipping!
# ECOR Exception Less than 200 Data points for today (180), skipping!
# HTBK Exception Less than 200 Data points for today (191), skipping!
# 101 2305 2020-12-16
# PCPL Exception Less than 200 Data points for today (166), skipping!
# CURO Exception Less than 200 Data points for today (112), skipping!
# TDY Exception Less than 200 Data points for today (196), skipping!
# TCMD Exception Less than 200 Data points for today (186), skipping!
# EPC Exception Less than 200 Data points for today (191), skipping!
# SCHL Exception Less than 200 Data points for today (158), skipping!
# ERII Exception Less than 200 Data points for today (194), skipping!
# BLI Exception Less than 200 Data points for today (192), skipping!
# BIO Exception Less than 200 Data points for today (181), skipping!
# SXT Exception Less than 200 Data points for today (152), skipping!
# AXAS Exception Less than 200 Data points for today (120), skipping!
# BHAT Exception Less than 200 Data points for today (194), skipping!
# 201 2305 2020-12-16
# LASR Exception Less than 200 Data points for today (183), skipping!
# NVR Exception Less than 200 Data points for today (196), skipping!
# AIMC Exception Less than 200 Data points for today (184), skipping!
# ORN Exception Less than 200 Data points for today (168), skipping!
# RAIL Exception Less than 200 Data points for today (156), skipping!
# 301 2305 2020-12-16
# GLOB Exception Less than 200 Data points for today (181), skipping!
# KRA Exception Less than 200 Data points for today (194), skipping!
# SOAC Exception Less than 200 Data points for today (149), skipping!
# ANPC Exception Less than 200 Data points for today (148), skipping!
# CNSP Exception Less than 200 Data points for today (107), skipping!
# LKCO Exception Less than 200 Data points for today (166), skipping!
# PRTA Exception Less than 200 Data points for today (192), skipping!
# KT Exception Less than 200 Data points for today (171), skipping!
# TISI Exception Less than 200 Data points for today (152), skipping!
# IBP Exception Less than 200 Data points for today (192), skipping!
# 401 2305 2020-12-16
# SLP Exception Less than 200 Data points for today (166), skipping!
# BNED Exception Less than 200 Data points for today (142), skipping!
# GLRE Exception Less than 200 Data points for today (190), skipping!
# AEIS Exception Less than 200 Data points for today (176), skipping!
# ILPT Exception Less than 200 Data points for today (198), skipping!
# HVT Exception Less than 200 Data points for today (182), skipping!
# REED Exception Less than 200 Data points for today (192), skipping!
# 501 2305 2020-12-16
# KNSA Exception Less than 200 Data points for today (171), skipping!
# GTYH Exception Less than 200 Data points for today (111), skipping!
# BAP Exception Less than 200 Data points for today (195), skipping!
# 601 2305 2020-12-16
# TAST Exception Less than 200 Data points for today (192), skipping!
# MHO Exception Less than 200 Data points for today (190), skipping!
# CWBR Exception Less than 200 Data points for today (186), skipping!
# LDL Exception Less than 200 Data points for today (196), skipping!
# TLSA Exception Less than 200 Data points for today (176), skipping!
# MBRX Exception Less than 200 Data points for today (178), skipping!
# SMMT Exception Less than 200 Data points for today (177), skipping!
# 701 2305 2020-12-16
# MLI Exception Less than 200 Data points for today (189), skipping!
# FFIC Exception Less than 200 Data points for today (160), skipping!
# PBFX Exception Less than 200 Data points for today (189), skipping!
# CRNT Exception Less than 200 Data points for today (183), skipping!
# GSBD Exception Less than 200 Data points for today (189), skipping!
# TSLX Exception Less than 200 Data points for today (198), skipping!
# ITRI Exception Less than 200 Data points for today (179), skipping!
# CBZ Exception Less than 200 Data points for today (186), skipping!
# 801 2305 2020-12-16
# SPH Exception Less than 200 Data points for today (174), skipping!
# VREX Exception Less than 200 Data points for today (178), skipping!
# SMP Exception Less than 200 Data points for today (155), skipping!
# HOLI Exception Less than 200 Data points for today (192), skipping!
# METX Exception Less than 200 Data points for today (115), skipping!
# ACIU Exception Less than 200 Data points for today (172), skipping!
# BVXV Exception Less than 200 Data points for today (170), skipping!
# OSPN Exception Less than 200 Data points for today (194), skipping!
# UMH Exception Less than 200 Data points for today (189), skipping!
# RAPT Exception Less than 200 Data points for today (185), skipping!
# CSII Exception Less than 200 Data points for today (192), skipping!
# CQP Exception Less than 200 Data points for today (193), skipping!
# 901 2305 2020-12-16
# NVRO Exception Less than 200 Data points for today (199), skipping!
# AKRO Exception Less than 200 Data points for today (155), skipping!
# VAPO Exception Less than 200 Data points for today (155), skipping!
# B Exception Less than 200 Data points for today (190), skipping!
# TNET Exception Less than 200 Data points for today (191), skipping!
# ACMR Exception Less than 200 Data points for today (162), skipping!
# AVAV Exception Less than 200 Data points for today (178), skipping!
# WEI Exception Less than 200 Data points for today (151), skipping!
# FUL Exception Less than 200 Data points for today (188), skipping!
# SSTK Exception Less than 200 Data points for today (175), skipping!
# ATNM Exception Less than 200 Data points for today (196), skipping!
# 1001 2305 2020-12-16
# NXTC Exception Less than 200 Data points for today (198), skipping!
# MLND Exception Less than 200 Data points for today (191), skipping!
# BDR Exception Less than 200 Data points for today (135), skipping!
# 1101 2305 2020-12-16
# RNA Exception Less than 200 Data points for today (165), skipping!
# BFAM Exception Less than 200 Data points for today (194), skipping!
# RYTM Exception Less than 200 Data points for today (173), skipping!
# PLIN Exception Less than 200 Data points for today (184), skipping!
# XCUR Exception Less than 200 Data points for today (160), skipping!
# CIO Exception Less than 200 Data points for today (164), skipping!
# AUB Exception Less than 200 Data points for today (182), skipping!
# TREE Exception Less than 200 Data points for today (186), skipping!
# 1201 2305 2020-12-16
# HFRO Exception Less than 200 Data points for today (133), skipping!
# ENSG Exception Less than 200 Data points for today (152), skipping!
# ENTX Exception Less than 200 Data points for today (190), skipping!
# 1301 2305 2020-12-16
# GOLF Exception Less than 200 Data points for today (179), skipping!
# TCBI Exception Less than 200 Data points for today (183), skipping!
# LGIH Exception Less than 200 Data points for today (198), skipping!
# ATRO Exception Less than 200 Data points for today (187), skipping!
# KIN Exception Less than 200 Data points for today (195), skipping!
# LPL Exception Less than 200 Data points for today (183), skipping!
# BIMI Exception Less than 200 Data points for today (183), skipping!
# GRTS Exception Less than 200 Data points for today (186), skipping!
# SCYX Exception Less than 200 Data points for today (115), skipping!
# 1401 2305 2020-12-16
# TMST Exception Less than 200 Data points for today (199), skipping!
# ASC Exception Less than 200 Data points for today (191), skipping!
# CRY Exception Less than 200 Data points for today (197), skipping!
# CTB Exception Less than 200 Data points for today (180), skipping!
# APEN Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# MGTX Exception Less than 200 Data points for today (161), skipping!
# LPTX Exception Less than 200 Data points for today (185), skipping!
# GEF Exception Less than 200 Data points for today (190), skipping!
# PRIM Exception Less than 200 Data points for today (160), skipping!
# NUS Exception Less than 200 Data points for today (192), skipping!
# 1501 2305 2020-12-16
# ACA Exception Less than 200 Data points for today (176), skipping!
# CSGP Exception Less than 200 Data points for today (159), skipping!
# IPGP Exception Less than 200 Data points for today (180), skipping!
# TOUR Exception Less than 200 Data points for today (198), skipping!
# HTLD Exception Less than 200 Data points for today (198), skipping!
# MWK Exception Less than 200 Data points for today (169), skipping!
# YMAB Exception Less than 200 Data points for today (192), skipping!
# WIFI Exception Less than 200 Data points for today (182), skipping!
# LOGC Exception Less than 200 Data points for today (167), skipping!
# NPA Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# 1601 2305 2020-12-16
# CCM Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# ENVA Exception Less than 200 Data points for today (182), skipping!
# CDTX Exception Less than 200 Data points for today (149), skipping!
# FENG Exception Less than 200 Data points for today (152), skipping!
# AGS Exception Less than 200 Data points for today (184), skipping!
# WYY Exception Less than 200 Data points for today (198), skipping!
# 1701 2305 2020-12-16
# XPEL Exception Less than 200 Data points for today (198), skipping!
# EME Exception Less than 200 Data points for today (193), skipping!
# EXPO Exception Less than 200 Data points for today (173), skipping!
# AZRE Exception Less than 200 Data points for today (179), skipping!
# HPR Exception Less than 200 Data points for today (192), skipping!
# 1801 2305 2020-12-16
# QNST Exception Less than 200 Data points for today (191), skipping!
# PETQ Exception Less than 200 Data points for today (198), skipping!
# HONE Exception Less than 200 Data points for today (193), skipping!
# NFBK Exception Less than 200 Data points for today (190), skipping!
# SGRY Exception Less than 200 Data points for today (195), skipping!
# ARQT Exception Less than 200 Data points for today (169), skipping!
# AIHS Exception Less than 200 Data points for today (183), skipping!
# GRNQ Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# 1901 2305 2020-12-16
# FAMI Exception Less than 200 Data points for today (193), skipping!
# BPT Exception Less than 200 Data points for today (157), skipping!
# SXTC Exception Less than 200 Data points for today (197), skipping!
# CAJ Exception Less than 200 Data points for today (190), skipping!
# BHLB Exception Less than 200 Data points for today (175), skipping!
# BCOR Exception Less than 200 Data points for today (163), skipping!
# TTI Exception Less than 200 Data points for today (199), skipping!
# FN Exception Less than 200 Data points for today (182), skipping!
# LCI Exception Less than 200 Data points for today (151), skipping!
# REVG Exception Less than 200 Data points for today (174), skipping!
# ALBO Exception Less than 200 Data points for today (152), skipping!
# MOTS Exception Less than 200 Data points for today (125), skipping!
# 2001 2305 2020-12-16
# CSGS Exception Less than 200 Data points for today (168), skipping!
# ALLK Exception Less than 200 Data points for today (195), skipping!
# VVOS Exception Less than 200 Data points for today (181), skipping!
# 2101 2305 2020-12-16
# SMCI Exception Less than 200 Data points for today (191), skipping!
# KOP Exception Less than 200 Data points for today (153), skipping!
# AGLE Exception Less than 200 Data points for today (189), skipping!
# ASPN Exception Less than 200 Data points for today (157), skipping!
# PTY Exception Less than 200 Data points for today (180), skipping!
# DIOD Exception Less than 200 Data points for today (195), skipping!
# NVG Exception Less than 200 Data points for today (182), skipping!
# 2201 2305 2020-12-16
# EPAM Exception Less than 200 Data points for today (190), skipping!
# INGN Exception Less than 200 Data points for today (186), skipping!
# ZUMZ Exception Less than 200 Data points for today (181), skipping!
# HZON Exception Less than 200 Data points for today (128), skipping!
# CWT Exception Less than 200 Data points for today (198), skipping!
# 2301 2305 2020-12-16
# CYTH Exception Less than 200 Data points for today (76), skipping!
# 1 2305 2020-12-17
# VIE Exception Less than 200 Data points for today (183), skipping!
# CFR Exception Less than 200 Data points for today (176), skipping!
# TFFP Exception Less than 200 Data points for today (198), skipping!
# IGMS Exception Less than 200 Data points for today (199), skipping!
# ECOR Exception Less than 200 Data points for today (186), skipping!
# ADCT Exception Less than 200 Data points for today (147), skipping!
# 101 2305 2020-12-17
# CURO Exception Less than 200 Data points for today (110), skipping!
# TBBK Exception Less than 200 Data points for today (193), skipping!
# WOW Exception Less than 200 Data points for today (170), skipping!
# TCMD Exception Less than 200 Data points for today (166), skipping!
# SOGO Exception Less than 200 Data points for today (199), skipping!
# ERII Exception Less than 200 Data points for today (162), skipping!
# AXAS Exception Less than 200 Data points for today (170), skipping!
# BHAT Exception Less than 200 Data points for today (182), skipping!
# 201 2305 2020-12-17
# GBIO Exception Less than 200 Data points for today (191), skipping!
# 301 2305 2020-12-17
# ANIX Exception Less than 200 Data points for today (151), skipping!
# SOAC Exception Less than 200 Data points for today (138), skipping!
# ANPC Exception Less than 200 Data points for today (149), skipping!
# TFSL Exception Less than 200 Data points for today (189), skipping!
# TISI Exception Less than 200 Data points for today (152), skipping!
# 401 2305 2020-12-17
# SLP Exception Less than 200 Data points for today (160), skipping!
# BNED Exception Less than 200 Data points for today (186), skipping!
# 501 2305 2020-12-17
# GDV Exception Less than 200 Data points for today (162), skipping!
# NDRA Exception Less than 200 Data points for today (184), skipping!
# ETY Exception Less than 200 Data points for today (142), skipping!
# MREO Exception Less than 200 Data points for today (195), skipping!
# CUB Exception Less than 200 Data points for today (193), skipping!
# XNCR Exception Less than 200 Data points for today (182), skipping!
# 601 2305 2020-12-17
# PLD Exception Null found in df_i columns: ['close', 'sma9', 'sma180', 'vwap', 'sma9_var', 'sma180_var', 'vwap_var', 'prev_close_var', 'prev_floor_var', 'prev_ceil_var', 'prev1_candle_score', 'prev2_candle_score', 'prev3_candle_score'], skipping!
# TAST Exception Less than 200 Data points for today (176), skipping!
# LDL Exception Less than 200 Data points for today (150), skipping!
# 701 2305 2020-12-17
# MLI Exception Less than 200 Data points for today (195), skipping!
# OSW Exception Less than 200 Data points for today (160), skipping!
# TFX Exception Less than 200 Data points for today (195), skipping!
# ALRN Exception Less than 200 Data points for today (130), skipping!
# MDGL Exception Less than 200 Data points for today (144), skipping!
# 801 2305 2020-12-17
# ACIU Exception Less than 200 Data points for today (195), skipping!
# BVXV Exception Less than 200 Data points for today (190), skipping!
# RAPT Exception Less than 200 Data points for today (195), skipping!
# CQP Exception Less than 200 Data points for today (166), skipping!
# 901 2305 2020-12-17
# B Exception Less than 200 Data points for today (197), skipping!
# ACMR Exception Less than 200 Data points for today (178), skipping!
# OSMT Exception Less than 200 Data points for today (176), skipping!
# ATNM Exception Less than 200 Data points for today (173), skipping!
# 1001 2305 2020-12-17
# RCEL Exception Less than 200 Data points for today (192), skipping!
# SAFM Exception Less than 200 Data points for today (192), skipping!
# TBPH Exception Less than 200 Data points for today (181), skipping!
# BDR Exception Less than 200 Data points for today (147), skipping!
# 1101 2305 2020-12-17
# CIO Exception Less than 200 Data points for today (166), skipping!
# DSKE Exception Less than 200 Data points for today (167), skipping!
# AUB Exception Less than 200 Data points for today (195), skipping!
# TREE Exception Less than 200 Data points for today (188), skipping!
# 1201 2305 2020-12-17
# ADTN Exception Less than 200 Data points for today (160), skipping!
# MOH Exception Less than 200 Data points for today (187), skipping!
# SD Exception Less than 200 Data points for today (150), skipping!
# IRT Exception Less than 200 Data points for today (188), skipping!
# TAC Exception Less than 200 Data points for today (188), skipping!
# AMN Exception Less than 200 Data points for today (195), skipping!
# 1301 2305 2020-12-17
# GOLF Exception Less than 200 Data points for today (178), skipping!
# BIMI Exception Less than 200 Data points for today (186), skipping!
# 1401 2305 2020-12-17
# AHH Exception Less than 200 Data points for today (190), skipping!
# ASC Exception Less than 200 Data points for today (189), skipping!
# CRY Exception Less than 200 Data points for today (189), skipping!
# APEN Exception Less than 200 Data points for today (154), skipping!
# LPTX Exception Less than 200 Data points for today (131), skipping!
# GEF Exception Less than 200 Data points for today (199), skipping!
# PRIM Exception Less than 200 Data points for today (196), skipping!
# 1501 2305 2020-12-17
# MITO Exception Less than 200 Data points for today (154), skipping!
# ACA Exception Less than 200 Data points for today (187), skipping!
# LEU Exception Less than 200 Data points for today (182), skipping!
# NAD Exception Less than 200 Data points for today (192), skipping!
# TOUR Exception Less than 200 Data points for today (195), skipping!
# YMAB Exception Less than 200 Data points for today (158), skipping!
# 1601 2305 2020-12-17
# GXGX Exception Less than 200 Data points for today (146), skipping!
# VC Exception Less than 200 Data points for today (175), skipping!
# CCM Exception Less than 200 Data points for today (135), skipping!
# ENVA Exception Less than 200 Data points for today (175), skipping!
# KRMD Exception Less than 200 Data points for today (191), skipping!
# 1701 2305 2020-12-17
# ENS Exception Less than 200 Data points for today (184), skipping!
# CLEU Exception Less than 200 Data points for today (169), skipping!
# SND Exception Less than 200 Data points for today (161), skipping!
# HPR Exception Less than 200 Data points for today (181), skipping!
# 1801 2305 2020-12-17
# QNST Exception Less than 200 Data points for today (194), skipping!
# PETQ Exception Less than 200 Data points for today (184), skipping!
# SGRY Exception Less than 200 Data points for today (189), skipping!
# AIHS Exception Less than 200 Data points for today (174), skipping!
# SPB Exception Less than 200 Data points for today (198), skipping!
# 1901 2305 2020-12-17
# BPMP Exception Less than 200 Data points for today (186), skipping!
# SXTC Exception Less than 200 Data points for today (187), skipping!
# HARP Exception Less than 200 Data points for today (178), skipping!
# CAJ Exception Less than 200 Data points for today (188), skipping!
# USCR Exception Less than 200 Data points for today (198), skipping!
# BCOR Exception Less than 200 Data points for today (188), skipping!
# FN Exception Less than 200 Data points for today (192), skipping!
# REVG Exception Less than 200 Data points for today (194), skipping!
# 2001 2305 2020-12-17
# CSGS Exception Less than 200 Data points for today (196), skipping!
# STC Exception Less than 200 Data points for today (152), skipping!
# SCHN Exception Less than 200 Data points for today (172), skipping!
# 2101 2305 2020-12-17
# WHD Exception Less than 200 Data points for today (195), skipping!
# BV Exception Less than 200 Data points for today (197), skipping!
# IMAB Exception Less than 200 Data points for today (182), skipping!
# PTY Exception Less than 200 Data points for today (192), skipping!
# MOD Exception Less than 200 Data points for today (186), skipping!
# XAN Exception Less than 200 Data points for today (182), skipping!
# 2201 2305 2020-12-17
# INGN Exception Less than 200 Data points for today (147), skipping!
# RVT Exception Less than 200 Data points for today (189), skipping!
# HZON Exception Less than 200 Data points for today (132), skipping!
# RDHL Exception Less than 200 Data points for today (172), skipping!
# CAAS Exception Less than 200 Data points for today (197), skipping!
# CWT Exception Less than 200 Data points for today (181), skipping!
# MEDP Exception Less than 200 Data points for today (189), skipping!
# 2301 2305 2020-12-17
# CYTH Exception Null found in df_i columns: ['sma180', 'sma180_var'], skipping!
# 1 2305 2020-12-18
# VRS Exception Less than 200 Data points for today (177), skipping!
# SITE Exception Less than 200 Data points for today (192), skipping!
# CODI Exception Less than 200 Data points for today (185), skipping!
# TFFP Exception Less than 200 Data points for today (194), skipping!
# 101 2305 2020-12-18
# PCPL Exception Less than 200 Data points for today (194), skipping!
# TCMD Exception Less than 200 Data points for today (185), skipping!
# SOGO Exception Less than 200 Data points for today (179), skipping!
# PTAC Exception Less than 200 Data points for today (143), skipping!
# BIO Exception Less than 200 Data points for today (125), skipping!
# AXAS Exception Less than 200 Data points for today (199), skipping!
# HSTO Exception Less than 200 Data points for today (181), skipping!
# 201 2305 2020-12-18
# MRTN Exception Less than 200 Data points for today (192), skipping!
# AIMC Exception Less than 200 Data points for today (180), skipping!
# RAIL Exception Less than 200 Data points for today (180), skipping!
# 301 2305 2020-12-18
# ANIX Exception Less than 200 Data points for today (101), skipping!
# CVGI Exception Less than 200 Data points for today (158), skipping!
# ANPC Exception Less than 200 Data points for today (164), skipping!
# NWG Exception Less than 200 Data points for today (187), skipping!
# IBP Exception Less than 200 Data points for today (171), skipping!
# 401 2305 2020-12-18
# ANCN Exception Less than 200 Data points for today (180), skipping!
# GLRE Exception Less than 200 Data points for today (195), skipping!
# ZLAB Exception Less than 200 Data points for today (166), skipping!
# HVT Exception Less than 200 Data points for today (165), skipping!
# 501 2305 2020-12-18
# SWM Exception Less than 200 Data points for today (199), skipping!
# GDV Exception Less than 200 Data points for today (180), skipping!
# ETY Exception Less than 200 Data points for today (183), skipping!
# WTS Exception Less than 200 Data points for today (183), skipping!
# BAP Exception Less than 200 Data points for today (197), skipping!
# GVA Exception Less than 200 Data points for today (163), skipping!
# BKNG Exception Less than 200 Data points for today (176), skipping!
# 601 2305 2020-12-18
# LDL Exception Less than 200 Data points for today (160), skipping!
# BAK Exception Less than 200 Data points for today (177), skipping!
# 701 2305 2020-12-18
# TFX Exception Less than 200 Data points for today (195), skipping!
# PBFX Exception Less than 200 Data points for today (192), skipping!
# CRNT Exception Less than 200 Data points for today (194), skipping!
# ALRN Exception Less than 200 Data points for today (162), skipping!
# ALTR Exception Less than 200 Data points for today (198), skipping!
# CBZ Exception Less than 200 Data points for today (184), skipping!
# 801 2305 2020-12-18
# MRAM Exception Less than 200 Data points for today (189), skipping!
# DAVA Exception Less than 200 Data points for today (142), skipping!
# GOOD Exception Less than 200 Data points for today (183), skipping!
# BVXV Exception Less than 200 Data points for today (152), skipping!
# 901 2305 2020-12-18
# TRTX Exception Less than 200 Data points for today (189), skipping!
# RBBN Exception Less than 200 Data points for today (191), skipping!
# B Exception Less than 200 Data points for today (188), skipping!
# HAPP Exception Less than 200 Data points for today (170), skipping!
# AVAV Exception Less than 200 Data points for today (189), skipping!
# OSMT Exception Less than 200 Data points for today (192), skipping!
# 1001 2305 2020-12-18
# BDR Exception Less than 200 Data points for today (92), skipping!
# AAT Exception Less than 200 Data points for today (198), skipping!
# 1101 2305 2020-12-18
# SYBX Exception Less than 200 Data points for today (197), skipping!
# ENV Exception Less than 200 Data points for today (195), skipping!
# DSKE Exception Less than 200 Data points for today (146), skipping!
# 1201 2305 2020-12-18
# SD Exception Less than 200 Data points for today (138), skipping!
# CHH Exception Less than 200 Data points for today (181), skipping!
# ENSG Exception Less than 200 Data points for today (173), skipping!
# CLDT Exception Less than 200 Data points for today (166), skipping!
# ENTX Exception Less than 200 Data points for today (172), skipping!
# 1301 2305 2020-12-18
# NEW Exception Less than 200 Data points for today (151), skipping!
# CHY Exception Less than 200 Data points for today (154), skipping!
# TCBI Exception Less than 200 Data points for today (180), skipping!
# KIN Exception Less than 200 Data points for today (155), skipping!
# LPL Exception Less than 200 Data points for today (186), skipping!
# 1401 2305 2020-12-18
# ASC Exception Less than 200 Data points for today (189), skipping!
# APEN Exception Less than 200 Data points for today (107), skipping!
# BRBR Exception Less than 200 Data points for today (172), skipping!
# PRIM Exception Less than 200 Data points for today (184), skipping!
# 1501 2305 2020-12-18
# MITO Exception Less than 200 Data points for today (176), skipping!
# MANH Exception Less than 200 Data points for today (192), skipping!
# NAD Exception Less than 200 Data points for today (184), skipping!
# CMRX Exception Less than 200 Data points for today (139), skipping!
# EVLO Exception Less than 200 Data points for today (167), skipping!
# YMAB Exception Less than 200 Data points for today (198), skipping!
# AWR Exception Less than 200 Data points for today (194), skipping!
# 1601 2305 2020-12-18
# GXGX Exception Less than 200 Data points for today (178), skipping!
# NRK Exception Less than 200 Data points for today (155), skipping!
# NBSE Exception Less than 200 Data points for today (184), skipping!
# UTG Exception Less than 200 Data points for today (187), skipping!
# INFI Exception Less than 200 Data points for today (193), skipping!
# WYY Exception Less than 200 Data points for today (181), skipping!
# 1701 2305 2020-12-18
# ENS Exception Less than 200 Data points for today (177), skipping!
# CLEU Exception Less than 200 Data points for today (178), skipping!
# FRG Exception Less than 200 Data points for today (191), skipping!
# SND Exception Less than 200 Data points for today (121), skipping!
# DNP Exception Less than 200 Data points for today (184), skipping!
# HPR Exception Less than 200 Data points for today (198), skipping!
# 1801 2305 2020-12-18
# SAH Exception Less than 200 Data points for today (184), skipping!
# FBM Exception Less than 200 Data points for today (161), skipping!
# IGR Exception Less than 200 Data points for today (185), skipping!
# BDJ Exception Less than 200 Data points for today (169), skipping!
# GRNQ Exception Less than 200 Data points for today (132), skipping!
# CCRN Exception Less than 200 Data points for today (189), skipping!
# 1901 2305 2020-12-18
# MMYT Exception Less than 200 Data points for today (175), skipping!
# BPT Exception Less than 200 Data points for today (138), skipping!
# PIRS Exception Less than 200 Data points for today (198), skipping!
# HARP Exception Less than 200 Data points for today (187), skipping!
# UTF Exception Less than 200 Data points for today (185), skipping!
# LE Exception Less than 200 Data points for today (192), skipping!
# BCOR Exception Less than 200 Data points for today (171), skipping!
# LCI Exception Less than 200 Data points for today (187), skipping!
# REVG Exception Less than 200 Data points for today (194), skipping!
# GSKY Exception Less than 200 Data points for today (181), skipping!
# 2001 2305 2020-12-18
# CSGS Exception Less than 200 Data points for today (199), skipping!
# SCHN Exception Less than 200 Data points for today (157), skipping!
# PRLB Exception Less than 200 Data points for today (198), skipping!
# COLM Exception Less than 200 Data points for today (192), skipping!
# SNP Exception Less than 200 Data points for today (176), skipping!
# 2101 2305 2020-12-18
# WHD Exception Less than 200 Data points for today (192), skipping!
# BSM Exception Less than 200 Data points for today (152), skipping!
# ARLP Exception Less than 200 Data points for today (184), skipping!
# BV Exception Less than 200 Data points for today (196), skipping!
# TCPC Exception Less than 200 Data points for today (198), skipping!
# NMCO Exception Less than 200 Data points for today (148), skipping!
# MIND Exception Less than 200 Data points for today (96), skipping!
# CW Exception Less than 200 Data points for today (182), skipping!
# PCRX Exception Less than 200 Data points for today (194), skipping!
# 2201 2305 2020-12-18
# INGN Exception Less than 200 Data points for today (199), skipping!
# RVT Exception Less than 200 Data points for today (191), skipping!
# HZON Exception Less than 200 Data points for today (172), skipping!
# HAE Exception Less than 200 Data points for today (194), skipping!
# RDHL Exception Less than 200 Data points for today (177), skipping!
# CWT Exception Less than 200 Data points for today (163), skipping!
# TDG Exception Less than 200 Data points for today (182), skipping!
# 2301 2305 2020-12-18
# Errors: 812 11525 0.07

# %%
# df_train - Create dataframe
if ls_df_t:
    df_t = pd.concat(ls_df_t)

# df_train - cleanup columns and NAs
ls_col = [
    'is_profit',
    'rsi14',
    'sma9_var',
    'sma180_var',
    'vwap_var',
    'spread14_e',
    'volume14_34_var',
    'prev_close_var',
    'prev_floor_var',
    'prev_ceil_var',
    'prev1_candle_score',
    'prev2_candle_score',
    'prev3_candle_score',
    'mins_from_start',
    'valley_interval_mins',
    'valley_close_score',
    'valley_rsi_score',
    'day_open_var',
    'open_from_prev_close_var',
    'ceil_var',
    'floor_var',
    ###
    'sym',
    'datetime',
    'profit',
    'prev_close',
    'divergence',
]
df_t = df_t[ls_col]
df_t = df_t.dropna()
#cat_cols = df_t.select_dtypes(include=object).columns
#df_t[cat_cols] = df_t[cat_cols].fillna('none').astype('category')
print(df_t.info())

# df_train - Export
timestamp = datetime.datetime.now().strftime('%Y%m%d_%H%M')
f = os.path.join(dir_train, f'df_train_{timestamp}.parquet')
df_t.to_parquet(f)
print(f, 'saved!')
beeps()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33747 entries, 22 to 184
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   is_profit                 33747 non-null  bool
#  1   rsi14                     33747 non-null  float64
#  2   sma9_var                  33747 non-null  float64
#  3   sma180_var                33747 non-null  float64
#  4   vwap_var                  33747 non-null  float64
#  5   spread14_e                33747 non-null  float64
#  6   volume14_34_var           33747 non-null  float64
#  7   prev_close_var            33747 non-null  float64
#  8   prev_floor_var            33747 non-null  float64
#  9   prev_ceil_var             33747 non-null  float64
#  10  prev1_candle_score        33747 non-null  float64
#  11  prev2_candle_score        33747 non-null  float64
#  12  prev3_candle_score        33747 non-null  float64
#  13  mins_from_start           33747 non-null  float64
#  14  valley_interval_mins      33747 non-null  float64
#  15  valley_close_score        33747 non-null  float64
#  16  valley_rsi_score          33747 non-null  float64
#  17  day_open_var              33747 non-null  float64
#  18  open_from_prev_close_var  33747 non-null  float64
#  19  ceil_var                  33747 non-null  float64
#  20  floor_var                 33747 non-null  float64
#  21  sym                       33747 non-null  object
#  22  datetime                  33747 non-null  datetime64[ns]
#  23  profit                    33747 non-null  float64
#  24  prev_close                33747 non-null  float64
#  25  divergence                33747 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(22), object(2)
# memory usage: 6.7+ MB
# None
# D:/Michael/github_projects/five_minute_midas/data/train/df_train_20201220_1446.parquet saved!

# %% [markdown]
# # Debug

# %%
date_str = '2020-12-03'
live_data = 1
df_c = get_df_c('BYND', date_str, live_data, db, target_profit, target_loss)
df_c
# Out:
#                datetime       close        sma9      sma180      rsi14  \
# 0   2020-12-03 09:30:00  140.699997  138.554767  137.843928  86.772514
# 1   2020-12-03 09:31:00  141.644196  138.950789  137.864007  89.744043
# 2   2020-12-03 09:32:00  140.960007  139.288567  137.879007  76.357938
# 3   2020-12-03 09:33:00  140.750000  139.576345  137.892674  72.770016
# 4   2020-12-03 09:34:00  140.850006  139.865234  137.907229  73.410743
# ..                  ...         ...         ...         ...        ...
# 104 2020-12-03 11:14:00  141.524994  141.528544  140.172950  45.999271
# 105 2020-12-03 11:15:00  141.486893  141.481532  140.193323  45.047214
# 106 2020-12-03 11:16:00  141.529999  141.437088  140.216323  46.398883
# 107 2020-12-03 11:17:00  141.800003  141.455977  140.240378  54.026739
# 108 2020-12-03 11:18:13  141.679398  141.473687  140.263208  50.565258
#
#            vwap  sma9_var  sma180_var  vwap_var  spread14_e  ...  \
# 0    140.356664  0.015483    0.020720  0.002446    0.000761  ...
# 1    140.509232  0.019384    0.027420  0.008078    0.001602  ...
# 2    140.535142  0.012000    0.022346  0.003023    0.001653  ...
# 3    140.560061  0.008409    0.020721  0.001351    0.001461  ...
# 4    140.567085  0.007041    0.021339  0.002013    0.001361  ...
# ..          ...       ...         ...       ...         ...  ...
# 104  141.756592 -0.000025    0.009646 -0.001634    0.000655  ...
# 105  141.756167  0.000038    0.009227 -0.001900    0.000650  ...
# 106  141.755768  0.000657    0.009369 -0.001593    0.000610  ...
# 107  141.755513  0.002432    0.011121  0.000314    0.000741  ...
# 108  141.755513  0.001454    0.010097 -0.000537    0.000642  ...
#
#      day_open_var  open_from_prev_close_var        ceil  ceil_var       floor  \
# 0        0.000000                  0.015371  140.699997  0.000000  140.699997
# 1        0.006711                  0.015371  141.644196  0.000000  140.699997
# 2        0.001848                  0.015371  141.644196 -0.004830  140.699997
# 3        0.000355                  0.015371  141.644196 -0.006313  140.699997
# 4        0.001066                  0.015371  141.644196 -0.005607  140.699997
# ..            ...                       ...         ...       ...         ...
# 104      0.005864                  0.015371  143.250000 -0.012042  140.369995
# 105      0.005593                  0.015371  143.250000 -0.012308  140.369995
# 106      0.005899                  0.015371  143.250000 -0.012007  140.369995
# 107      0.007818                  0.015371  143.250000 -0.010122  140.369995
# 108      0.006961                  0.015371  143.250000 -0.010964  140.369995
#
#      floor_var   sym  actual_buy_price  profit  is_profit
# 0     0.000000  BYND        140.960007    None      False
# 1     0.006711  BYND        140.750000    None      False
# 2     0.001848  BYND        140.850006    None      False
# 3     0.000355  BYND        140.369995    None      False
# 4     0.001066  BYND        140.492905    None      False
# ..         ...   ...               ...     ...        ...
# 104   0.008228  BYND        141.529999    None      False
# 105   0.007957  BYND        141.800003    None      False
# 106   0.008264  BYND        141.679398    None      False
# 107   0.010187  BYND               NaN    None      False
# 108   0.009328  BYND               NaN    None      False
#
# [109 rows x 36 columns]
